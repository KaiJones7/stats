# %% [markdown]
# # Optimising models & SVMs
#
# In all the ML algorithms we have learnt so far, you have learnt a few hyperparameters and understood the general effects of them on each model. But how do we best set the hyperparameter to customise our models to our dataset? We can objectively search different values for model hyperparameters and choose a subset that results in a model that achieves the best performance - this is called **hyperparameter tuning / hyperparameter optimisation**.
#
# Today we will discover hyperparameter tuning using scikit-learn. We will first try it on some of the classification / regression models that you already know, then we will learn a new algorithm, **Support Vector Machines**, and apply hyperparameter tuning as well.
#
# ## Outline <a name="top"></a>
# 1. [House Price Data Preparation](#cleaning)
# 2. [Hyperparameter Tuning](#ht)
#     1. [Grid Search](#grid)
#     2. [Random Search](#random)
# 3. [Hyperparameter Tuning in Classification](#classification)
# 4. [Hyperparameter Tuning in Regression](#regression)
# 5. [Support Vector Machines](#svm)
# 6. [Activity](#activity)

# %%
### loading packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random as rand

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier


from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.impute import SimpleImputer
from sklearn.neighbors import NearestNeighbors

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import RandomizedSearchCV

from sklearn import svm

from sklearn.metrics import f1_score, precision_score, recall_score, cohen_kappa_score, roc_curve, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
#Here is the pip-free version: Our own ReSampler for imbalance in your target variable 

def ReSampler(X,y,Target,Ratio,Mode,Seed):
    X[Target] = y 
    df = X
    if (Mode == 0) or (Mode == "Over"):
        #Get the Minority Class
        MinorityClass=df[Target].value_counts().loc[df[Target].value_counts()==min(df[Target].value_counts())].index[0]

        #Get a df of only Minority Cases - for resampling
        Minoritydf=df[df[Target]==MinorityClass]

        #Find out how many samples we need in total
        TargetTotal=round(max(df[Target].value_counts())/(1-Ratio))

        #Find out how many of our sample need to be of the minority class, so the target ratio is reached
        SamplesNeeded=TargetTotal-len(df)

        #Initialise Resampled Df
        ResampledDf=pd.DataFrame(np.empty((0,len(Minoritydf.columns))))
        ResampledDf.columns=Minoritydf.columns

        #Draw with replacement from the Minority Dataframe to get as many Samples as needed
        ResampledDf=ResampledDf.append(Minoritydf.sample(int(SamplesNeeded), replace = True, axis = 0,random_state=Seed))

        NewDf=df.append(ResampledDf)
    elif (Mode == 1) or (Mode == "Under"):
        #Get the Majority Class and Minority Class
        MajorityClass=df[Target].value_counts().loc[df[Target].value_counts()==max(df[Target].value_counts())].index[0]
        MinorityClass=df[Target].value_counts().loc[df[Target].value_counts()!=max(df[Target].value_counts())].index[0]

        #Get a df of only Minority Cases - for the output
        Minoritydf=df[df[Target]==MinorityClass]

        #Get a df of only Majority Classes - for resampling
        Majoritydf=df[df[Target]==MajorityClass]
        
        #Find out how many samples we need in total
        TargetTotal=round(min(df[Target].value_counts())/(1-Ratio))
        
        #Find out how many of our sample need to be of the majority class, so the target ratio is reached
        SamplesNeeded=TargetTotal-len(df)

        #get a list of random numbers the length of Majoritydf
        nums=list(range(len(Majoritydf)))

        #randomly reorder these numbers and draw an amount from them equal to the length of the Minoritydf
        rand.Random(Seed).shuffle(nums)
        nums=nums[0:SamplesNeeded]

        #Now use that shorter list of numbers to slice Majoritydf - so you you only select a random subset of that df that has the
        #length of Minoritydf
        Majoritydf=Majoritydf.iloc[nums,:]

        #Recombine the two df
        NewDf=Minoritydf.append(Majoritydf)
    elif (Mode == 2) or (Mode == "SMOTE"):
        #Get the Minority Class
        MajorityClass=df[Target].value_counts().loc[df[Target].value_counts()==max(df[Target].value_counts())].index[0]
        MinorityClass=df[Target].value_counts().loc[df[Target].value_counts()==min(df[Target].value_counts())].index[0]
        
        #Get a Dataframe of the MinorityClass
        Minoritydf=df[df[Target]==MinorityClass]
        
        #Get a df of only Majority Classes - for resampling
        Majoritydf=df[df[Target]==MajorityClass]
        
        #Standardise that dataframe (writign our own StandardScaler here is more efficient, because it saves us converting for DataFrame to array and back)
        StandardMinoritydf=Minoritydf.copy()
        for i in range(len(StandardMinoritydf.columns)):
            if Minoritydf.iloc[:,i].astype("float").std()==0:
                StandardMinoritydf.iloc[:,i]=(Minoritydf.iloc[:,i].astype("float")-Minoritydf.iloc[:,i].astype("float").mean())
            else:
                StandardMinoritydf.iloc[:,i]=(Minoritydf.iloc[:,i].astype("float")-Minoritydf.iloc[:,i].astype("float").mean())/Minoritydf.iloc[:,i].astype("float").std()
        
        #Initiate Nearest Neighbour Algorythm - we do 5 neighbours, as suggested in the original SMOTE paper
        Neigh=NearestNeighbors(n_neighbors=5, algorithm='ball_tree')
        
        #Preallocating an empty dataframe with the same columns as our input
        ResampledDf=pd.DataFrame(np.empty((0,len(Minoritydf.columns))))
        ResampledDf.columns=Minoritydf.columns
        
        #Preallocating a counter for the loop
        k=1
        
        #Setting a seed
        np.random.seed(Seed)
        
        #The Main SMOTE Loop - go until the Minority data is [Ratio] percent of all data
        while (len(StandardMinoritydf))/(len(StandardMinoritydf)+len(Majoritydf)) < Ratio:
            
            #get a random number for picking a random row of data later
            i=rand.randint(0,len(StandardMinoritydf)-1)
            
            #get a random number for picking a random one of the datapoint's 5 nearest neighbours later
            j=rand.randint(0,4)
            
            #Find the 5 nearest neighbours of all current datapoints
            Neigh.fit(StandardMinoritydf)
            _, indices = Neigh.kneighbors()
            
            #Create a new datapoint that lies exactly between a randomly chosen original datapoint, and one of its nearest neighbours (randomly chosen)
            ResampledDf=pd.DataFrame((StandardMinoritydf.iloc[i,:].astype("float")+StandardMinoritydf.iloc[indices[i][j]].astype("float"))/2).transpose()
            
            #Give that new datapoint an index that counts up from the highest index number in the original dataset
            ResampledDf.index=range(df.index.max()+k,df.index.max()+k+1)
            
            #Add the new datapoint to the standardised dataframe containing all data from the minority class
            StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
            
            #Increase the loop counter
            k+=1

        #For my sanity, make a copy of the now SMOTEed, but still standardised dataframe
        NewDf=StandardMinoritydf.copy()
        
        #Reverse the Standardisation process by multiplying all data by the original standard deviations of their columns, and adding their columns original means
        for i in range(len(NewDf.columns)):
            if Minoritydf.iloc[:,i].astype("float").std()==0:
                NewDf.iloc[:,i]=(StandardMinoritydf.iloc[:,i].astype("float")+Minoritydf.iloc[:,i].astype("float").mean())
            else:
                NewDf.iloc[:,i]=(StandardMinoritydf.iloc[:,i].astype("float")*Minoritydf.iloc[:,i].astype("float").std())+Minoritydf.iloc[:,i].astype("float").mean()
        
        #Unite the (SMOTEed) Minority data with the Majority data - ready to eject!
        NewDf=Majoritydf.append(NewDf)
    NewX = NewDf.drop(columns = [Target])
    Newy = NewDf[Target]
    return NewX, Newy

# %%
## Impute missing values using Simple Imputation method - let's impute our numerical values with 'mean' value and the categorical with 'most_frequent'
### Since we need to impute on both X_train and X_test separately, let's use a function to avoid repeating ourselves!!

def impute_missing_values(df):
    # Separate numerical and categorical features
    num_features = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
    cat_features = df.select_dtypes(include=['object']).columns.tolist()

    # Create separate SimpleImputer instances for numerical and categorical features
    num_imputer = SimpleImputer(strategy='mean')
    cat_imputer = SimpleImputer(strategy='most_frequent')

    # Impute missing values in numerical features
    df_num = df[num_features]
    df_num_imputed = num_imputer.fit_transform(df_num)

    # Convert the imputed numerical features back to a DataFrame
    df_num_imputed_df = pd.DataFrame(df_num_imputed, columns=num_features)

    # Impute missing values in categorical features
    df_cat = df[cat_features]
    df_cat_imputed = cat_imputer.fit_transform(df_cat)

    # Convert the imputed categorical features back to a DataFrame
    df_cat_imputed_df = pd.DataFrame(df_cat_imputed, columns=cat_features)

    # Combine the numerical and categorical DataFrames back into one DataFrame
    df_imputed = pd.concat([df_num_imputed_df, df_cat_imputed_df], axis=1)
    
    return df_imputed

# %%
# While we are on the function train, let's have another function that allows you to print the performance metric for each class balancing method 

def get_classification_results(truth, prediction, df, idx):

    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_probs)
    kappa = cohen_kappa_score(y_test, y_pred)

    df.loc[idx,:] = [acc, f1, precision, recall, auc, kappa]

    return df

# %%
def get_reg_results(truth, prediction, df, idx):
    '''
    This function generates a results dataframe given your y_test and predictions. 
    It allows you to take the output of this function and put it into the next time you call the function
    Filling out the entirity of the dataframe one function call (and row) at a time
    Inputs:
    - truth = y_test, the actual values
    - prediction = your predictions
    - df = a dataframe that is already set up to hold our data. 
    - idx = the method that you are using (which corresponds to a row index)
    Output:
    - the input df, but with another row filled out
    '''
    
    mse_int = mean_squared_error(y_test, y_pred)
    mse = round(mse_int, 3)
    rmse = round((mse_int)**0.5, 3)
    mae = round(mean_absolute_error(y_test, y_pred), 3)
    
    SS_Residual = sum((truth-prediction)**2)       
    SS_Total = sum((truth-np.mean(truth))**2)     
    r_squared = 1 - (float(SS_Residual))/SS_Total
    
    r2 = round(r_squared, 3)
    
    df.loc[idx, :] = [rmse, mae, r2]
    
    return df

# %% [markdown]
# ## Data Preparation <a name="cleaning"></a>
#
# You have guessed it right - its the London House Price Dataset again for demonstration!
#
# You already know the cleaning process. It's exactly the same as in previous workshops.

# %%
## Read in comma separated file 

df = pd.read_csv('../CSV files/london_house_price_data.csv',index_col = [0])
df.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-b9a510bdb6e4> in <module>
#       1 ## Read in comma separated file
#       2
# ----> 3 df = pd.read_csv('../CSV files/london_house_price_data.csv',index_col = [0])
#       4 df.info()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../CSV files/london_house_price_data.csv'

# %%
def clean(df):
    ## Removing columns 
    byebye_col = ['link','address','description','added_date','sold_date','agent','postcode', 'borough']
    df = df.drop(columns = byebye_col)
    
    # Remove word "miles" in column "distance_to_station"
    df['distance_to_station'] = df['distance_to_station'].str.replace(' miles', '').astype('float')
    
    # Combining the property type of bungalow into house 
    df['property_type'] = df['property_type'].replace(['Detached Bungalow', 'Retirement Property', 'Semi-Detached Bungalow'], 'House')
    
    # Remove column leasehold_years_left
    df = df.drop('leasehold_years_left', axis = 1)
    
    # Dropping rows with target variable missing
    df.dropna(subset=['sold_under_90days'], inplace=True)
    df['sold_under_90days'] = df['sold_under_90days'].astype(int)
    
    return df

# %%
df = clean(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1379 entries, 0 to 1467
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   saleprice            1379 non-null   float64
#  1   property_type        1379 non-null   object
#  2   bedrooms             1379 non-null   int64
#  3   bathrooms            1379 non-null   int64
#  4   distance_to_station  1379 non-null   float64
#  5   tenure               1188 non-null   object
#  6   crime_rate           1021 non-null   float64
#  7   total_area           1379 non-null   float64
#  8   year_built           1379 non-null   int64
#  9   property_condition   1379 non-null   float64
#  10  amenities_rating     1379 non-null   float64
#  11  garden               1379 non-null   bool
#  12  balcony              1379 non-null   bool
#  13  fuel_type            1379 non-null   object
#  14  sold_under_90days    1379 non-null   int64
# dtypes: bool(2), float64(6), int64(4), object(3)
# memory usage: 153.5+ KB

# %%
# extract the target for classification and regression accordingly
X_class = df.drop(columns = ['sold_under_90days'])
y_class = df['sold_under_90days']

X_reg = df.drop(columns = ['saleprice'])
y_reg = df['saleprice']

# %%
# Train Test Split with on target variable for Classification
X_train, X_test, y_train, y_test = train_test_split(X_class, y_class,test_size=0.2,random_state=456)

# %%
# Resetting index to make sure our ReSampler function works
X_train.reset_index(drop=True, inplace = True)
y_train.reset_index(drop=True, inplace = True)

# Imputataion
X_train_imputed = impute_missing_values(X_train)
X_test_imputed = impute_missing_values(X_test)

## One-hot encoding on categorical columsn before training the model 
X_train_encoded = pd.get_dummies(X_train_imputed, columns=['property_type','tenure','fuel_type'])
X_test_encoded = pd.get_dummies(X_test_imputed, columns=['property_type', 'tenure','fuel_type'])

# %% [markdown]
# ## Hyperparmeter Tuning <a name="ht"></a>
#
#
# A **“parameter”** is a configuration variable that is internal to the model and whose value can be estimated from the data.
# A **“hyperparameter”** is a configuration that is external to the model and whose value cannot be estimate from the data.
#
# Hyperparameters are model parameters whose values are set before training. For example, the number of trees in a random forest or the penalty intensity of a Lasso regression. They are all numbers that are set before the training phase and their values affect the behavior of the model. A model with different hyperparameters is, actually, a different model so it may have a lower performance.
#
# If the model has several hyperparameters, we need to find the best combination of values of the hyperparameters searching in a multi-dimensional space. That’s why hyperparameter tuning, which is the process of finding the right values of the hyperparameters, is a very complex and time-expensive task.
#
# There are more than one way for hyperparameter tuning, but we will focus on **Grid Search** for demonstration.
#
# ### Grid Search <a name="grid"></a>
#
# Grid search is the simplest algorithm for hyperparameter tuning. We divide the domain of the hyperparameters into a discrete grid. We then try every combination of values of this grid, calculating some performance metrics using cross-validation. The point of the grid that maximizes the average value in cross-validation, is the optimal combination of values for the hyperparameters.
#
# <img src="gridsearch.png" width="550" align="center">
#
#
#
# **Cross Validation**
#
# Cross validation is the best practice for tuning a model. It allows you to split your training data into n versions of training + validation data sets. You then build n models, averaging the performance metric of choice. In a one off tuning without a validation set, you may overfit the data or have selection bias present. Since you **do not (ever!) use your test data to select your best performing model**, you may accidentially choose an inferior model as the best one. Using the average performance of n different models trained on n different datasets will protect you from these sources of error and allow you to select the best tuning parameters.
#
# <img src="CV.png" width="550" align="center">
#
#
# Grid search is an exhaustive algorithm in order to find the best point in the domain. The biggest drawback is that it’s very slow. Checking every combination of the space requires a lot of time that and sometimes we might not have that time for it... Don’t forget that every point in the grid needs k-fold cross-validation, which requires k training steps. Grid search can be expensive and slow but if we want the best combination of values of the hyperparmeters, it can help us to achieve that.
#
# We will use [gridsearchcv](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) from sklearn. It creates a grid of all of your parameter values and tests all possible combinations - using cross validation to select the best ones from the training data.
#
# For classification model demo, we will be using random forest and gradient boost, tuning on the purity metric used (criterion), depth of the tree (max_depth), and the minimum number of resulting observations required to accept a spliit (min_samples_leaf). The idea is to look at how varying the size (depth) and complexity (number of nodes) impacts our performance. We will also tune the learning rate which controls the shrinkage of each tree for gradient boost.
#
# For regression model demo, we will be using lasso and ridge, tuning on alpha. You can also use the [repeated kfold function](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RepeatedKFold.html) as your strategy - where we will set the number of folds in our cv, a random state, and the number of times to repeat the cv. Additionally, we will set the scoring function to be rmse as it is popular to use and reports values on the same scale as your outcome.
#
# *Note: n_jobs parameter in gridsearchcv is the number of jobs to run in parallel. -1 will use all the processors. I set it to 3 so that I can still run other scripts/programs on my computer if the model takes a long time to run. These won't, but a neural network can take 8+ hours*
#
#
# ### Random Search <a name="random"></a>
#
# Random search is similar to grid search, but instead of using all the points in the grid, it tests only a randomly selected subset of these points. The smaller this subset, the faster but less accurate the optimization. The larger this dataset, the more accurate the optimization but the closer to a grid search.Random search is a very useful option when you have several hyperparameters with a fine-grained grid of values. Using a subset made by 5-100 randomly selected points, we are able to get a reasonably good set of values of the hyperparameters. It will not likely be the best point, but it can still be a good set of values that gives us a good model.
#
# [RandomizedSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.htmlhttps://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html) function is here for you to explore!

# %% [markdown]
# ## Hyperparameter Tuning on Classification models <a name="classification"></a>

# %%
# We are tuning a random forest, so let's make a dictionary for all that models parameters
rfDict = {'n_estimators':[100,250,500],
              'max_depth': [5,10,25],
              'min_samples_split': [2,4,6],
              'min_samples_leaf': [1,2,4]} 
#These aren't all the params of a forest - but we are already asking for 81 jobs (that is, models). 
#That is not even taking into account cross validation (which will multiply this number further), so let's see what happens.

# %%
#Build an empty Forest:
rf = RandomForestClassifier(random_state = 423) #setting a seed here will mean the bootstrapping will always be performed the same - making the hyperparameters more comparable

# %%
#Initialise the Grid Search with the Forrest and the Dictionary
rf_class = GridSearchCV(rf, rfDict, n_jobs=1,
                        verbose = 3, # setting verbose = 3 gives us some information about all the fits, so we see what's happening as we wait and don't get bored...
                        cv = 3, # Cross Validation can be useful... but time intensive. Default here is five... so set this down to 3, which is a reasonable min.
                        scoring = 'accuracy')

# %%
#Fit the training data to perform the grid search (TRAINING ONLY! DON'T USE ALL YOUR DATA - OTHERWISE YOU'LL HAVE SPILLAGE!)
rf_class.fit(X_train_encoded, y_train)
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# [CV 1/3] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.774 total time=   0.4s
# [CV 2/3] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.799 total time=   0.3s
# [CV 3/3] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.812 total time=   0.3s
# [CV 1/3] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.783 total time=   0.8s
# [CV 2/3] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.796 total time=   0.7s
# [CV 3/3] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.807 total time=   0.7s
# [CV 1/3] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=0.777 total time=   1.4s
# [CV 2/3] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=0.793 total time=   1.6s
# [CV 3/3] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=0.807 total time=   1.7s
# [CV 1/3] END max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.772 total time=   0.3s
# [CV 2/3] END max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.799 total time=   0.3s
# [CV 3/3] END max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.804 total time=   0.3s
# [CV 1/3] END max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=250;, score=0.780 total time=   0.7s
# [CV 2/3] END max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=250;, score=0.793 total time=   0.8s
# [CV 3/3] END max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=250;, score=0.804 total time=   0.7s
# [CV 1/3] END max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=500;, score=0.777 total time=   1.3s
# [CV 2/3] END max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=500;, score=0.796 total time=   1.5s
# [CV 3/3] END max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=500;, score=0.804 total time=   1.5s
# [CV 1/3] END max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.766 total time=   0.5s
# [CV 2/3] END max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.793 total time=   0.4s
# [CV 3/3] END max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.804 total time=   0.3s
# [CV 1/3] END max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=250;, score=0.772 total time=   0.7s
# [CV 2/3] END max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=250;, score=0.802 total time=   0.7s
# [CV 3/3] END max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=250;, score=0.801 total time=   0.7s
# [CV 1/3] END max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=500;, score=0.777 total time=   1.4s
# [CV 2/3] END max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=500;, score=0.802 total time=   1.7s
# [CV 3/3] END max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=500;, score=0.801 total time=   2.2s
# [CV 1/3] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.774 total time=   0.4s
# [CV 2/3] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.796 total time=   0.3s
# [CV 3/3] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.804 total time=   0.3s
# [CV 1/3] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.777 total time=   0.7s
# [CV 2/3] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.796 total time=   0.7s
# [CV 3/3] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.793 total time=   0.7s
# [CV 1/3] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=0.774 total time=   1.4s
# [CV 2/3] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=0.796 total time=   2.2s
# [CV 3/3] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=0.807 total time=   1.6s
# [CV 1/3] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.774 total time=   0.4s
# [CV 2/3] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.796 total time=   0.4s
# [CV 3/3] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.804 total time=   0.6s
# [CV 1/3] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.777 total time=   1.6s
# [CV 2/3] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.796 total time=   2.5s
# [CV 3/3] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.793 total time=   1.4s
# [CV 1/3] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=500;, score=0.774 total time=   2.1s
# [CV 2/3] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=500;, score=0.796 total time=   2.3s
# [CV 3/3] END max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=500;, score=0.807 total time=   1.4s
# [CV 1/3] END max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.766 total time=   0.3s
# [CV 2/3] END max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.793 total time=   0.5s
# [CV 3/3] END max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.807 total time=   0.3s
# [CV 1/3] END max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=250;, score=0.772 total time=   1.0s
# [CV 2/3] END max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=250;, score=0.802 total time=   0.7s
# [CV 3/3] END max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=250;, score=0.801 total time=   0.7s
# [CV 1/3] END max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=500;, score=0.774 total time=   1.3s
# [CV 2/3] END max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=500;, score=0.796 total time=   1.8s
# [CV 3/3] END max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=500;, score=0.798 total time=   1.5s
# [CV 1/3] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.777 total time=   0.3s
# [CV 2/3] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.802 total time=   0.4s
# [CV 3/3] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.807 total time=   0.3s
# [CV 1/3] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.774 total time=   0.7s
# [CV 2/3] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.802 total time=   0.7s
# [CV 3/3] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.798 total time=   0.7s
# [CV 1/3] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=500;, score=0.772 total time=   1.5s
# [CV 2/3] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=500;, score=0.796 total time=   1.6s
# [CV 3/3] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=500;, score=0.804 total time=   1.5s
# [CV 1/3] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.777 total time=   0.4s
# [CV 2/3] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.802 total time=   0.3s
# [CV 3/3] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.807 total time=   0.6s
# [CV 1/3] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.774 total time=   0.7s
# [CV 2/3] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.802 total time=   0.7s
# [CV 3/3] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.798 total time=   0.7s
# [CV 1/3] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=500;, score=0.772 total time=   1.3s
# [CV 2/3] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=500;, score=0.796 total time=   1.7s
# [CV 3/3] END max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=500;, score=0.804 total time=   1.6s
# [CV 1/3] END max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.777 total time=   0.4s
# [CV 2/3] END max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.802 total time=   0.3s
# [CV 3/3] END max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.807 total time=   0.3s
# [CV 1/3] END max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=250;, score=0.774 total time=   0.7s
# [CV 2/3] END max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=250;, score=0.802 total time=   0.7s
# [CV 3/3] END max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=250;, score=0.798 total time=   0.7s
# [CV 1/3] END max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=500;, score=0.772 total time=   1.3s
# [CV 2/3] END max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=500;, score=0.796 total time=   1.5s
# [CV 3/3] END max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=500;, score=0.804 total time=   1.5s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.769 total time=   0.4s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.793 total time=   0.5s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.809 total time=   0.3s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.780 total time=   0.8s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.793 total time=   0.8s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.804 total time=   0.8s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=0.780 total time=   1.7s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=0.793 total time=   3.0s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=0.815 total time=   1.6s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.764 total time=   0.4s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.796 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.809 total time=   0.3s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=250;, score=0.772 total time=   0.9s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=250;, score=0.796 total time=   1.1s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=250;, score=0.817 total time=   1.1s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=500;, score=0.769 total time=   2.7s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=500;, score=0.802 total time=   1.8s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=500;, score=0.823 total time=   1.6s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.777 total time=   0.3s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.793 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.801 total time=   0.3s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=250;, score=0.769 total time=   0.9s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=250;, score=0.799 total time=   1.0s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=250;, score=0.817 total time=   0.8s
# [CV 1/3] END max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=500;, score=0.772 total time=   1.5s
# [CV 2/3] END max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=500;, score=0.793 total time=   1.6s
# [CV 3/3] END max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=500;, score=0.817 total time=   2.0s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.769 total time=   0.6s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.791 total time=   0.4s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.817 total time=   0.4s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.769 total time=   0.9s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.799 total time=   0.9s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.815 total time=   0.8s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=0.777 total time=   1.6s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=0.793 total time=   1.6s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=0.817 total time=   1.5s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.769 total time=   0.3s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.791 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.817 total time=   0.3s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.769 total time=   0.8s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.799 total time=   0.8s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.815 total time=   0.8s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=500;, score=0.777 total time=   1.7s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=500;, score=0.793 total time=   1.6s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=500;, score=0.817 total time=   1.6s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.755 total time=   0.3s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.796 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.817 total time=   0.3s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=250;, score=0.766 total time=   0.8s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=250;, score=0.799 total time=   0.9s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=250;, score=0.817 total time=   0.7s
# [CV 1/3] END max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=500;, score=0.769 total time=   1.5s
# [CV 2/3] END max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=500;, score=0.796 total time=   1.6s
# [CV 3/3] END max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=500;, score=0.817 total time=   1.5s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.769 total time=   0.3s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.802 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.809 total time=   0.3s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.772 total time=   0.7s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.802 total time=   0.7s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.817 total time=   0.7s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500;, score=0.777 total time=   1.5s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500;, score=0.799 total time=   1.6s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500;, score=0.812 total time=   1.6s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.769 total time=   0.3s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.802 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.809 total time=   0.4s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.772 total time=   0.8s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.802 total time=   0.8s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.817 total time=   0.7s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=500;, score=0.777 total time=   2.0s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=500;, score=0.799 total time=   1.5s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=500;, score=0.812 total time=   1.5s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.769 total time=   0.3s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.802 total time=   0.3s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.809 total time=   0.3s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=250;, score=0.772 total time=   0.7s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=250;, score=0.802 total time=   0.7s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=250;, score=0.817 total time=   0.8s
# [CV 1/3] END max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=500;, score=0.777 total time=   1.5s
# [CV 2/3] END max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=500;, score=0.799 total time=   1.6s
# [CV 3/3] END max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=500;, score=0.812 total time=   1.5s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.769 total time=   0.4s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.783 total time=   0.3s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.798 total time=   0.3s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.769 total time=   0.8s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.785 total time=   0.8s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=250;, score=0.793 total time=   0.9s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=0.766 total time=   1.8s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=0.791 total time=   1.7s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=500;, score=0.804 total time=   1.7s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.769 total time=   0.3s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.791 total time=   0.4s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=100;, score=0.804 total time=   0.3s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=250;, score=0.774 total time=   0.8s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=250;, score=0.799 total time=   0.8s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=250;, score=0.798 total time=   0.8s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=500;, score=0.783 total time=   1.6s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=500;, score=0.793 total time=   1.8s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=500;, score=0.807 total time=   1.7s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.777 total time=   0.4s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.793 total time=   0.4s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.809 total time=   0.4s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=250;, score=0.772 total time=   0.8s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=250;, score=0.791 total time=   0.9s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=250;, score=0.809 total time=   0.8s
# [CV 1/3] END max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=500;, score=0.783 total time=   1.7s
# [CV 2/3] END max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=500;, score=0.788 total time=   1.7s
# [CV 3/3] END max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=500;, score=0.809 total time=   1.8s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.761 total time=   0.3s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.788 total time=   0.3s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.798 total time=   0.3s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.769 total time=   0.8s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.791 total time=   0.8s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=250;, score=0.804 total time=   0.8s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=0.769 total time=   1.6s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=0.791 total time=   1.7s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=500;, score=0.817 total time=   2.0s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.761 total time=   0.4s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.788 total time=   0.4s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=100;, score=0.798 total time=   0.3s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.769 total time=   0.8s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.791 total time=   0.8s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=250;, score=0.804 total time=   0.8s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=500;, score=0.769 total time=   1.6s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=500;, score=0.791 total time=   1.6s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=500;, score=0.817 total time=   1.6s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.766 total time=   0.3s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.793 total time=   0.3s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.801 total time=   0.3s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=250;, score=0.772 total time=   0.8s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=250;, score=0.791 total time=   0.8s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=250;, score=0.812 total time=   0.8s
# [CV 1/3] END max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=500;, score=0.772 total time=   2.1s
# [CV 2/3] END max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=500;, score=0.796 total time=   1.7s
# [CV 3/3] END max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=500;, score=0.812 total time=   1.8s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.764 total time=   0.3s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.810 total time=   0.3s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.807 total time=   0.3s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.769 total time=   0.8s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.799 total time=   0.9s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=250;, score=0.817 total time=   0.8s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=500;, score=0.772 total time=   2.2s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=500;, score=0.799 total time=   2.5s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=500;, score=0.809 total time=   2.0s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.764 total time=   0.9s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.810 total time=   0.4s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=100;, score=0.807 total time=   0.4s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.769 total time=   0.9s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.799 total time=   0.9s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=250;, score=0.817 total time=   0.9s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=500;, score=0.772 total time=   1.9s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=500;, score=0.799 total time=   1.7s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=500;, score=0.809 total time=   1.9s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.764 total time=   0.4s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.810 total time=   0.6s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=100;, score=0.807 total time=   0.5s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=250;, score=0.769 total time=   1.0s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=250;, score=0.799 total time=   1.0s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=250;, score=0.817 total time=   0.9s
# [CV 1/3] END max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=500;, score=0.772 total time=   1.8s
# [CV 2/3] END max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=500;, score=0.799 total time=   1.7s
# [CV 3/3] END max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=500;, score=0.809 total time=   1.7s
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=423), n_jobs=1,
#              param_grid={'max_depth': [5, 10, 25],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 4, 6],
#                          'n_estimators': [100, 250, 500]},
#              scoring='accuracy', verbose=3)

# %%
# Let's get the grid search results
GridResults=pd.DataFrame(rf_class.cv_results_) # We make them a pandas dataframe, just it because it looks nice
GridResults=GridResults.sort_values("rank_test_score") #And we sort them by rank
GridResults
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 32       1.919612      0.468777         0.093650        0.018840
# 52       0.715979      0.038818         0.043580        0.001558
# 49       0.748214      0.033201         0.044152        0.003420
# 46       0.684530      0.006472         0.042665        0.000623
# 38       1.482456      0.032553         0.084759        0.005550
# ..            ...           ...              ...             ...
# 69       0.302522      0.001327         0.019457        0.000793
# 54       0.329156      0.009911         0.021663        0.002449
# 66       0.333898      0.025835         0.025191        0.006951
# 63       0.305774      0.003093         0.020491        0.001786
# 55       0.790496      0.031982         0.045779        0.001687
#
#    param_max_depth param_min_samples_leaf param_min_samples_split  \
# 32              10                      1                       4
# 52              10                      4                       6
# 49              10                      4                       4
# 46              10                      4                       2
# 38              10                      2                       2
# ..             ...                    ...                     ...
# 69              25                      2                       6
# 54              25                      1                       2
# 66              25                      2                       4
# 63              25                      2                       2
# 55              25                      1                       2
#
#    param_n_estimators                                             params  \
# 32                500  {'max_depth': 10, 'min_samples_leaf': 1, 'min_...
# 52                250  {'max_depth': 10, 'min_samples_leaf': 4, 'min_...
# 49                250  {'max_depth': 10, 'min_samples_leaf': 4, 'min_...
# 46                250  {'max_depth': 10, 'min_samples_leaf': 4, 'min_...
# 38                500  {'max_depth': 10, 'min_samples_leaf': 2, 'min_...
# ..                ...                                                ...
# 69                100  {'max_depth': 25, 'min_samples_leaf': 2, 'min_...
# 54                100  {'max_depth': 25, 'min_samples_leaf': 1, 'min_...
# 66                100  {'max_depth': 25, 'min_samples_leaf': 2, 'min_...
# 63                100  {'max_depth': 25, 'min_samples_leaf': 2, 'min_...
# 55                250  {'max_depth': 25, 'min_samples_leaf': 1, 'min_...
#
#     split0_test_score  split1_test_score  split2_test_score  mean_test_score  \
# 32           0.769022           0.801630           0.822888         0.797847
# 52           0.771739           0.801630           0.817439         0.796936
# 49           0.771739           0.801630           0.817439         0.796936
# 46           0.771739           0.801630           0.817439         0.796936
# 38           0.777174           0.793478           0.817439         0.796030
# ..                ...                ...                ...              ...
# 69           0.766304           0.793478           0.801090         0.786958
# 54           0.769022           0.782609           0.798365         0.783332
# 66           0.760870           0.788043           0.798365         0.782426
# 63           0.760870           0.788043           0.798365         0.782426
# 55           0.769022           0.785326           0.792916         0.782421
#
#     std_test_score  rank_test_score
# 32        0.022153                1
# 52        0.018950                2
# 49        0.018950                2
# 46        0.018950                2
# 38        0.016537                5
# ..             ...              ...
# 69        0.014931               77
# 54        0.011990               78
# 66        0.015814               79
# 63        0.015814               79
# 55        0.009969               81
#
# [81 rows x 15 columns]

# %%
# Let's get the best estimator and use that as the model 
rf_model = rf_class.best_estimator_

y_pred = rf_model.predict(X_test_encoded)
y_probs = rf_model.predict_proba(X_test_encoded)[:, 1]  # Probability estimates of the positive class, need this to calculate auc

## Set up results df

results_class = pd.DataFrame(index = ['Random Forest', 'Gradient Boosting', 'SVM'], 
                       columns = ['accuracy', 'f1', 'precision', 'recall','auc','kappa']) #F1 is the harmonic mean of precision and recall.


results_class = get_classification_results(y_test, y_pred, results_class, 'Random Forest')


print('The best parameters are {}'.format(rf_class.best_params_))
# Out:
# The best parameters are {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 500}

# %%
results_class
# Out:
#                    accuracy        f1 precision    recall       auc     kappa
# Random Forest      0.789855  0.865741  0.802575  0.939698  0.813418  0.395879
# Gradient Boosting       NaN       NaN       NaN       NaN       NaN       NaN
# SVM                     NaN       NaN       NaN       NaN       NaN       NaN

# %%
## Let's try with gradient boost
gbDict = {'n_estimators':[100,250,500],
          'max_depth': [5,10,25],
          'min_samples_split': [2,4,6],
          'min_samples_leaf': [1,2,4],
          'learning_rate':[0.1,0.5,0.8]} 

gb = GradientBoostingClassifier(random_state = 423)

gb_class = GridSearchCV(gb, gbDict, n_jobs=1,
                        verbose = 2, # setting verbose = 2 displays a progress bar, with some information in the grid searching process, so we don't get bored...
                        cv = 3, # Cross Validation can be useful... but time intense. Default is five... so set this down to 3, which is a reasonable min.
                        scoring = 'accuracy') 

gb_class.fit(X_train_encoded, y_train) 

gb_model = gb_class.best_estimator_

y_pred = gb_model.predict(X_test_encoded)
y_probs = gb_model.predict_proba(X_test_encoded)[:, 1]  # Probability estimates of the positive class, need this to calculate auc


results_class = get_classification_results(y_test, y_pred, results_class, 'Gradient Boosting')


print('The best parameters are {}'.format(gb_class.best_params_))
# Out:
# Fitting 3 folds for each of 243 candidates, totalling 729 fits
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   3.7s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   3.0s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   3.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   2.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   2.4s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.4s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   2.8s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   2.4s
# [CV] END learning_rate=0.1, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   3.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   3.5s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   3.7s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   4.0s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   4.5s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   3.0s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   2.8s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   3.5s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   3.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.9s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   3.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   2.6s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   3.9s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   2.9s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   2.9s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   3.5s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   3.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   3.7s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   2.6s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   2.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   2.6s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   3.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   3.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   3.5s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   3.5s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   3.5s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   3.6s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.8s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   2.0s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   3.7s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   3.4s
# [CV] END learning_rate=0.1, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   3.4s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   2.6s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.8s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   2.9s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   2.3s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   2.4s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   2.9s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.7s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   3.4s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   3.7s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   3.5s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   3.5s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.4s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   3.7s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   3.5s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   3.5s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.8s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   1.8s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   3.8s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   3.5s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   3.6s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   3.9s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   3.9s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   4.1s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   4.3s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   3.5s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   3.4s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   3.9s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   3.8s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   3.7s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   3.7s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   4.0s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   4.1s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   3.9s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   4.3s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.5s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   1.2s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   3.4s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   3.8s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   4.5s
# [CV] END learning_rate=0.1, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   4.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   2.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   1.6s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   1.6s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   1.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   1.2s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   1.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   1.6s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   1.2s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   1.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   1.9s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.5, max_depth=5, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   1.9s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   0.9s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   0.9s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   0.9s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   0.9s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   1.1s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.5, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   0.9s
# ...
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   0.9s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   0.9s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=10, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   1.1s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=4, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   1.3s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=250; total time=   0.9s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   1.2s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   1.1s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=1, min_samples_split=6, n_estimators=500; total time=   1.1s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   1.1s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   1.0s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=250; total time=   1.0s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   1.3s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   1.2s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=4, n_estimators=500; total time=   1.3s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=250; total time=   1.0s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   0.9s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=2, min_samples_split=6, n_estimators=500; total time=   0.9s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=250; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   0.9s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   0.8s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=4, n_estimators=500; total time=   1.0s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   0.7s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=250; total time=   1.2s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   1.5s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   1.1s
# [CV] END learning_rate=0.8, max_depth=25, min_samples_leaf=4, min_samples_split=6, n_estimators=500; total time=   0.9s
# The best parameters are {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 100}

# %%
results_class
# Out:
#                    accuracy        f1 precision    recall       auc     kappa
# Random Forest      0.789855  0.865741  0.802575  0.939698  0.813418  0.395879
# Gradient Boosting   0.76087  0.842857  0.800905  0.889447  0.789402  0.348544
# SVM                     NaN       NaN       NaN       NaN       NaN       NaN

# %% [markdown]
# ## Hyperparameter Tuning on Regression models <a name="regression"></a>

# %%
# Train Test Split with on target variable for Regression 
X_train, X_test, y_train, y_test = train_test_split(X_reg, y_reg,test_size=0.2,random_state=456)

# %%
#Defining Variable types
cat_vars = ['property_type', 'tenure', 'fuel_type','sold_under_90days']
num_vars = list(df.columns)
num_vars = [x for x in num_vars if x not in cat_vars]

# Resetting index to make sure our ReSampler function works
X_train.reset_index(drop=True, inplace = True)
y_train.reset_index(drop=True, inplace = True)

# Imputataion
X_train_imputed = impute_missing_values(X_train)
X_test_imputed = impute_missing_values(X_test)

## One-hot encoding on categorical columsn before training the model 
X_train_encoded = pd.get_dummies(X_train_imputed, columns=['property_type','tenure','fuel_type'])
X_test_encoded = pd.get_dummies(X_test_imputed, columns=['property_type', 'tenure','fuel_type'])

# Standardisation
scaler = StandardScaler()
scaler.fit(X_train_encoded[num_vars])
X_train_encoded.loc[:, num_vars] = scaler.transform(X_train_encoded.loc[:, num_vars])
X_test_encoded.loc[:,num_vars] = scaler.transform(X_test_encoded.loc[:, num_vars])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-668e75a997b3> in <module>
#      18 # Standardisation
#      19 scaler = StandardScaler()
# ---> 20 scaler.fit(X_train_encoded[num_vars])
#      21 X_train_encoded.loc[:, num_vars] = scaler.transform(X_train_encoded.loc[:, num_vars])
#      22 X_test_encoded.loc[:,num_vars] = scaler.transform(X_test_encoded.loc[:, num_vars])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6131
#    6132             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133             raise KeyError(f"{not_found} not in index")
#    6134
#    6135     @overload
#
# KeyError: "['saleprice', 'garden', 'balcony'] not in index"

# %%
X_train_encoded
# Out:
#       bedrooms  bathrooms  distance_to_station  crime_rate  total_area  \
# 0     0.904363  -0.668307             0.826828   -0.105854    1.913288
# 1    -1.186857  -0.668307             0.826828   -0.404973   -0.926341
# 2     0.904363   1.086795             0.144455   -0.165678    0.039057
# 3    -1.186857  -0.668307            -0.537918   -0.225501   -1.427257
# 4    -0.141247  -0.668307            -0.879104   -0.225501   -0.317118
# ...        ...        ...                  ...         ...         ...
# 1098 -1.186857  -0.668307             0.485642    0.000000   -0.729379
# 1099  1.949972  -0.668307             0.144455   -0.424914    0.108183
# 1100 -0.141247  -0.668307            -0.537918    0.000000   -1.705894
# 1101 -1.186857  -0.668307            -0.196731   -0.783858   -0.343127
# 1102  2.995582   1.086795            -0.196731    0.000000    2.983981
#
#       year_built  property_condition  amenities_rating  \
# 0       0.798816            1.727897          1.922179
# 1       0.979257           -1.284147         -0.084918
# 2       0.546198           -0.531136         -0.753950
# 3      -1.005595           -0.531136         -1.422983
# 4       0.870992            0.974886          0.584114
# ...          ...                 ...               ...
# 1098    0.798816           -0.531136          0.584114
# 1099   -0.536448           -0.531136         -1.422983
# 1100    1.087521            0.974886         -1.422983
# 1101    0.798816           -0.531136          0.584114
# 1102   -0.752977           -0.531136          1.253147
#
#       property_type_Bungalow  property_type_Flat  property_type_House  \
# 0                          0                   0                    1
# 1                          0                   1                    0
# 2                          0                   1                    0
# 3                          0                   0                    1
# 4                          0                   1                    0
# ...                      ...                 ...                  ...
# 1098                       0                   1                    0
# 1099                       0                   0                    1
# 1100                       0                   1                    0
# 1101                       0                   1                    0
# 1102                       0                   0                    1
#
#       tenure_Freehold  tenure_Leasehold  tenure_Share of freehold  \
# 0                   0                 1                         0
# 1                   0                 1                         0
# 2                   0                 1                         0
# 3                   1                 0                         0
# 4                   0                 1                         0
# ...               ...               ...                       ...
# 1098                0                 1                         0
# 1099                1                 0                         0
# 1100                0                 1                         0
# 1101                0                 1                         0
# 1102                0                 1                         0
#
#       fuel_type_electric  fuel_type_gas
# 0                      0              1
# 1                      0              1
# 2                      0              1
# 3                      0              1
# 4                      1              0
# ...                  ...            ...
# 1098                   1              0
# 1099                   1              0
# 1100                   1              0
# 1101                   0              1
# 1102                   1              0
#
# [1103 rows x 16 columns]

# %%
## Setting global parameters

parameters = {'alpha':np.arange(0.1, 5, .1)} # start, stop, step
# for lasso and ridge

# %%
## Fitting the LASSO model and making predictions

model = Lasso(random_state = 4, max_iter=20000) #alpha will be adjusted in the gridsearch
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

clf = GridSearchCV(model, parameters, cv = cv, n_jobs=1, scoring = 'neg_root_mean_squared_error',verbose=3)
# remember parameters is set above as a global parameter

clf.fit(X=X_train_encoded, y=y_train)
lasso_model = clf.best_estimator_

print('The best alpha value is {}'.format(clf.best_params_['alpha']))

y_pred = lasso_model.predict(X_test_encoded)

results_reg = pd.DataFrame(index = ['Lasso', 'Ridge'], columns = ['RMSE', 'MAE', 'R2'])

results_reg = get_reg_results(y_test, y_pred, results_reg, 'Lasso')
results_reg
# Out:
# Fitting 30 folds for each of 49 candidates, totalling 1470 fits
# [CV 1/30] END ..................alpha=0.1;, score=-142024.888 total time=   4.9s
# [CV 2/30] END ...................alpha=0.1;, score=-75466.469 total time=   0.0s
# [CV 3/30] END ...................alpha=0.1;, score=-79089.876 total time=   0.0s
# [CV 4/30] END ...................alpha=0.1;, score=-88235.848 total time=   0.0s
# [CV 5/30] END ...................alpha=0.1;, score=-66767.053 total time=   0.0s
# [CV 6/30] END ...................alpha=0.1;, score=-84272.782 total time=   0.0s
# [CV 7/30] END ...................alpha=0.1;, score=-80689.247 total time=   0.0s
# [CV 8/30] END ...................alpha=0.1;, score=-71971.829 total time=   0.0s
# [CV 9/30] END ...................alpha=0.1;, score=-89814.535 total time=   0.0s
# [CV 10/30] END ..................alpha=0.1;, score=-80913.887 total time=   0.0s
# [CV 11/30] END ..................alpha=0.1;, score=-72125.459 total time=   0.0s
# [CV 12/30] END ..................alpha=0.1;, score=-86222.907 total time=   0.0s
# [CV 13/30] END ..................alpha=0.1;, score=-86850.267 total time=   0.0s
# [CV 14/30] END ..................alpha=0.1;, score=-77875.117 total time=   0.0s
# [CV 15/30] END .................alpha=0.1;, score=-130489.990 total time=   0.0s
# [CV 16/30] END .................alpha=0.1;, score=-100190.990 total time=   0.0s
# [CV 17/30] END ..................alpha=0.1;, score=-89891.358 total time=   0.0s
# [CV 18/30] END ..................alpha=0.1;, score=-72443.374 total time=   0.0s
# [CV 19/30] END ..................alpha=0.1;, score=-74648.427 total time=   0.0s
# [CV 20/30] END ..................alpha=0.1;, score=-72510.337 total time=   0.0s
# [CV 21/30] END ..................alpha=0.1;, score=-92722.493 total time=   0.0s
# [CV 22/30] END ..................alpha=0.1;, score=-81800.644 total time=   0.0s
# [CV 23/30] END ..................alpha=0.1;, score=-80450.737 total time=   0.0s
# [CV 24/30] END ..................alpha=0.1;, score=-93383.906 total time=   0.0s
# [CV 25/30] END .................alpha=0.1;, score=-123916.382 total time=   0.0s
# [CV 26/30] END ..................alpha=0.1;, score=-71140.618 total time=   0.0s
# [CV 27/30] END ..................alpha=0.1;, score=-76693.727 total time=   0.0s
# [CV 28/30] END ..................alpha=0.1;, score=-80690.109 total time=   0.0s
# [CV 29/30] END ..................alpha=0.1;, score=-89973.573 total time=   0.0s
# [CV 30/30] END ..................alpha=0.1;, score=-78449.748 total time=   0.0s
# [CV 1/30] END ..................alpha=0.2;, score=-142024.821 total time=   0.0s
# [CV 2/30] END ...................alpha=0.2;, score=-75466.390 total time=   0.0s
# [CV 3/30] END ...................alpha=0.2;, score=-79089.967 total time=   0.0s
# [CV 4/30] END ...................alpha=0.2;, score=-88235.870 total time=   0.0s
# [CV 5/30] END ...................alpha=0.2;, score=-66766.982 total time=   0.0s
# [CV 6/30] END ...................alpha=0.2;, score=-84272.803 total time=   0.0s
# [CV 7/30] END ...................alpha=0.2;, score=-80689.186 total time=   0.0s
# [CV 8/30] END ...................alpha=0.2;, score=-71971.688 total time=   0.0s
# [CV 9/30] END ...................alpha=0.2;, score=-89814.435 total time=   0.0s
# [CV 10/30] END ..................alpha=0.2;, score=-80914.200 total time=   0.0s
# [CV 11/30] END ..................alpha=0.2;, score=-72125.316 total time=   0.0s
# [CV 12/30] END ..................alpha=0.2;, score=-86222.963 total time=   0.0s
# [CV 13/30] END ..................alpha=0.2;, score=-86850.261 total time=   0.0s
# [CV 14/30] END ..................alpha=0.2;, score=-77875.090 total time=   0.0s
# [CV 15/30] END .................alpha=0.2;, score=-130489.796 total time=   0.0s
# [CV 16/30] END .................alpha=0.2;, score=-100191.086 total time=   0.0s
# [CV 17/30] END ..................alpha=0.2;, score=-89891.343 total time=   0.0s
# [CV 18/30] END ..................alpha=0.2;, score=-72443.140 total time=   0.0s
# [CV 19/30] END ..................alpha=0.2;, score=-74648.451 total time=   0.0s
# [CV 20/30] END ..................alpha=0.2;, score=-72510.319 total time=   0.0s
# [CV 21/30] END ..................alpha=0.2;, score=-92722.468 total time=   0.0s
# [CV 22/30] END ..................alpha=0.2;, score=-81800.736 total time=   0.0s
# [CV 23/30] END ..................alpha=0.2;, score=-80450.751 total time=   0.0s
# [CV 24/30] END ..................alpha=0.2;, score=-93383.941 total time=   0.0s
# [CV 25/30] END .................alpha=0.2;, score=-123916.227 total time=   0.0s
# [CV 26/30] END ..................alpha=0.2;, score=-71140.533 total time=   0.0s
# [CV 27/30] END ..................alpha=0.2;, score=-76693.611 total time=   0.0s
# [CV 28/30] END ..................alpha=0.2;, score=-80690.030 total time=   0.0s
# [CV 29/30] END ..................alpha=0.2;, score=-89973.645 total time=   0.0s
# [CV 30/30] END ..................alpha=0.2;, score=-78449.752 total time=   0.0s
# [CV 1/30] END ..alpha=0.30000000000000004;, score=-142024.755 total time=   0.0s
# [CV 2/30] END ...alpha=0.30000000000000004;, score=-75466.311 total time=   0.0s
# [CV 3/30] END ...alpha=0.30000000000000004;, score=-79090.058 total time=   0.0s
# [CV 4/30] END ...alpha=0.30000000000000004;, score=-88235.891 total time=   0.0s
# [CV 5/30] END ...alpha=0.30000000000000004;, score=-66766.910 total time=   0.0s
# [CV 6/30] END ...alpha=0.30000000000000004;, score=-84272.825 total time=   0.0s
# [CV 7/30] END ...alpha=0.30000000000000004;, score=-80689.137 total time=   0.0s
# [CV 8/30] END ...alpha=0.30000000000000004;, score=-71971.549 total time=   0.0s
# [CV 9/30] END ...alpha=0.30000000000000004;, score=-89814.335 total time=   0.0s
# [CV 10/30] END ..alpha=0.30000000000000004;, score=-80914.513 total time=   0.0s
# [CV 11/30] END ..alpha=0.30000000000000004;, score=-72125.173 total time=   0.0s
# [CV 12/30] END ..alpha=0.30000000000000004;, score=-86223.020 total time=   0.0s
# [CV 13/30] END ..alpha=0.30000000000000004;, score=-86850.254 total time=   0.0s
# [CV 14/30] END ..alpha=0.30000000000000004;, score=-77875.062 total time=   0.0s
# [CV 15/30] END .alpha=0.30000000000000004;, score=-130489.606 total time=   0.0s
# [CV 16/30] END .alpha=0.30000000000000004;, score=-100191.185 total time=   0.0s
# [CV 17/30] END ..alpha=0.30000000000000004;, score=-89891.328 total time=   0.0s
# [CV 18/30] END ..alpha=0.30000000000000004;, score=-72442.905 total time=   0.0s
# [CV 19/30] END ..alpha=0.30000000000000004;, score=-74648.469 total time=   0.0s
# [CV 20/30] END ..alpha=0.30000000000000004;, score=-72510.278 total time=   0.0s
# [CV 21/30] END ..alpha=0.30000000000000004;, score=-92722.444 total time=   0.0s
# [CV 22/30] END ..alpha=0.30000000000000004;, score=-81800.829 total time=   0.0s
# [CV 23/30] END ..alpha=0.30000000000000004;, score=-80450.765 total time=   0.0s
# [CV 24/30] END ..alpha=0.30000000000000004;, score=-93383.977 total time=   0.0s
# [CV 25/30] END .alpha=0.30000000000000004;, score=-123916.072 total time=   0.0s
# [CV 26/30] END ..alpha=0.30000000000000004;, score=-71140.450 total time=   0.0s
# [CV 27/30] END ..alpha=0.30000000000000004;, score=-76693.469 total time=   0.0s
# [CV 28/30] END ..alpha=0.30000000000000004;, score=-80689.951 total time=   0.0s
# [CV 29/30] END ..alpha=0.30000000000000004;, score=-89973.708 total time=   0.0s
# [CV 30/30] END ..alpha=0.30000000000000004;, score=-78449.756 total time=   0.0s
# [CV 1/30] END ..................alpha=0.4;, score=-142024.689 total time=   0.0s
# [CV 2/30] END ...................alpha=0.4;, score=-75466.232 total time=   0.0s
# [CV 3/30] END ...................alpha=0.4;, score=-79090.147 total time=   0.0s
# [CV 4/30] END ...................alpha=0.4;, score=-88235.912 total time=   0.0s
# [CV 5/30] END ...................alpha=0.4;, score=-66766.841 total time=   0.0s
# [CV 6/30] END ...................alpha=0.4;, score=-84272.846 total time=   0.0s
# [CV 7/30] END ...................alpha=0.4;, score=-80689.069 total time=   0.0s
# [CV 8/30] END ...................alpha=0.4;, score=-71971.404 total time=   0.0s
# [CV 9/30] END ...................alpha=0.4;, score=-89814.234 total time=   0.0s
# [CV 10/30] END ..................alpha=0.4;, score=-80914.826 total time=   0.0s
# [CV 11/30] END ..................alpha=0.4;, score=-72125.029 total time=   0.0s
# [CV 12/30] END ..................alpha=0.4;, score=-86223.076 total time=   0.0s
# [CV 13/30] END ..................alpha=0.4;, score=-86850.248 total time=   0.0s
# [CV 14/30] END ..................alpha=0.4;, score=-77875.035 total time=   0.0s
# [CV 15/30] END .................alpha=0.4;, score=-130489.418 total time=   0.0s
# [CV 16/30] END .................alpha=0.4;, score=-100191.283 total time=   0.0s
# [CV 17/30] END ..................alpha=0.4;, score=-89891.313 total time=   0.0s
# [CV 18/30] END ..................alpha=0.4;, score=-72442.670 total time=   0.0s
# [CV 19/30] END ..................alpha=0.4;, score=-74648.487 total time=   0.0s
# [CV 20/30] END ..................alpha=0.4;, score=-72510.260 total time=   0.0s
# [CV 21/30] END ..................alpha=0.4;, score=-92722.420 total time=   0.0s
# [CV 22/30] END ..................alpha=0.4;, score=-81800.921 total time=   0.0s
# [CV 23/30] END ..................alpha=0.4;, score=-80450.780 total time=   0.0s
# [CV 24/30] END ..................alpha=0.4;, score=-93384.012 total time=   0.0s
# [CV 25/30] END .................alpha=0.4;, score=-123915.917 total time=   0.0s
# [CV 26/30] END ..................alpha=0.4;, score=-71140.366 total time=   0.0s
# [CV 27/30] END ..................alpha=0.4;, score=-76693.345 total time=   0.0s
# [CV 28/30] END ..................alpha=0.4;, score=-80689.872 total time=   0.0s
# [CV 29/30] END ..................alpha=0.4;, score=-89973.787 total time=   0.0s
# [CV 30/30] END ..................alpha=0.4;, score=-78449.760 total time=   0.0s
# [CV 1/30] END ..................alpha=0.5;, score=-142024.622 total time=   0.0s
# [CV 2/30] END ...................alpha=0.5;, score=-75466.155 total time=   0.0s
# [CV 3/30] END ...................alpha=0.5;, score=-79090.239 total time=   0.0s
# [CV 4/30] END ...................alpha=0.5;, score=-88235.933 total time=   0.0s
# [CV 5/30] END ...................alpha=0.5;, score=-66766.769 total time=   0.0s
# [CV 6/30] END ...................alpha=0.5;, score=-84272.867 total time=   0.0s
# [CV 7/30] END ...................alpha=0.5;, score=-80689.008 total time=   0.0s
# [CV 8/30] END ...................alpha=0.5;, score=-71971.264 total time=   0.0s
# [CV 9/30] END ...................alpha=0.5;, score=-89814.134 total time=   0.0s
# [CV 10/30] END ..................alpha=0.5;, score=-80915.134 total time=   0.0s
# [CV 11/30] END ..................alpha=0.5;, score=-72124.885 total time=   0.0s
# [CV 12/30] END ..................alpha=0.5;, score=-86223.132 total time=   0.0s
# [CV 13/30] END ..................alpha=0.5;, score=-86850.242 total time=   0.0s
# [CV 14/30] END ..................alpha=0.5;, score=-77875.005 total time=   0.0s
# [CV 15/30] END .................alpha=0.5;, score=-130489.231 total time=   0.0s
# [CV 16/30] END .................alpha=0.5;, score=-100191.381 total time=   0.0s
# [CV 17/30] END ..................alpha=0.5;, score=-89891.296 total time=   0.0s
# [CV 18/30] END ..................alpha=0.5;, score=-72442.433 total time=   0.0s
# [CV 19/30] END ..................alpha=0.5;, score=-74648.424 total time=   0.0s
# [CV 20/30] END ..................alpha=0.5;, score=-72510.254 total time=   0.0s
# [CV 21/30] END ..................alpha=0.5;, score=-92722.394 total time=   0.0s
# [CV 22/30] END ..................alpha=0.5;, score=-81801.013 total time=   0.0s
# [CV 23/30] END ..................alpha=0.5;, score=-80450.794 total time=   0.0s
# [CV 24/30] END ..................alpha=0.5;, score=-93384.047 total time=   0.0s
# [CV 25/30] END .................alpha=0.5;, score=-123915.761 total time=   0.0s
# [CV 26/30] END ..................alpha=0.5;, score=-71140.282 total time=   0.0s
# [CV 27/30] END ..................alpha=0.5;, score=-76693.271 total time=   0.0s
# [CV 28/30] END ..................alpha=0.5;, score=-80689.799 total time=   0.0s
# [CV 29/30] END ..................alpha=0.5;, score=-89973.846 total time=   0.0s
# [CV 30/30] END ..................alpha=0.5;, score=-78449.763 total time=   0.0s
# [CV 1/30] END ..................alpha=0.6;, score=-142024.556 total time=   0.0s
# [CV 2/30] END ...................alpha=0.6;, score=-75466.074 total time=   0.0s
# [CV 3/30] END ...................alpha=0.6;, score=-79090.329 total time=   0.0s
# [CV 4/30] END ...................alpha=0.6;, score=-88235.955 total time=   0.0s
# [CV 5/30] END ...................alpha=0.6;, score=-66766.702 total time=   0.0s
# [CV 6/30] END ...................alpha=0.6;, score=-84272.889 total time=   0.0s
# [CV 7/30] END ...................alpha=0.6;, score=-80688.965 total time=   0.0s
# [CV 8/30] END ...................alpha=0.6;, score=-71971.124 total time=   0.0s
# [CV 9/30] END ...................alpha=0.6;, score=-89814.034 total time=   0.0s
# [CV 10/30] END ..................alpha=0.6;, score=-80915.452 total time=   0.0s
# [CV 11/30] END ..................alpha=0.6;, score=-72124.744 total time=   0.0s
# [CV 12/30] END ..................alpha=0.6;, score=-86223.189 total time=   0.0s
# [CV 13/30] END ..................alpha=0.6;, score=-86850.236 total time=   0.0s
# [CV 14/30] END ..................alpha=0.6;, score=-77874.979 total time=   0.0s
# [CV 15/30] END .................alpha=0.6;, score=-130489.042 total time=   0.0s
# [CV 16/30] END .................alpha=0.6;, score=-100191.481 total time=   0.0s
# [CV 17/30] END ..................alpha=0.6;, score=-89891.281 total time=   0.0s
# [CV 18/30] END ..................alpha=0.6;, score=-72442.198 total time=   0.0s
# [CV 19/30] END ..................alpha=0.6;, score=-74648.524 total time=   0.0s
# [CV 20/30] END ..................alpha=0.6;, score=-72510.224 total time=   0.0s
# [CV 21/30] END ..................alpha=0.6;, score=-92722.371 total time=   0.0s
# [CV 22/30] END ..................alpha=0.6;, score=-81801.107 total time=   0.0s
# [CV 23/30] END ..................alpha=0.6;, score=-80450.809 total time=   0.0s
# [CV 24/30] END ..................alpha=0.6;, score=-93384.082 total time=   0.0s
# [CV 25/30] END .................alpha=0.6;, score=-123915.606 total time=   0.0s
# [CV 26/30] END ..................alpha=0.6;, score=-71140.199 total time=   0.0s
# [CV 27/30] END ..................alpha=0.6;, score=-76693.098 total time=   0.0s
# [CV 28/30] END ..................alpha=0.6;, score=-80689.714 total time=   0.0s
# [CV 29/30] END ..................alpha=0.6;, score=-89973.915 total time=   0.0s
# [CV 30/30] END ..................alpha=0.6;, score=-78449.767 total time=   0.0s
# [CV 1/30] END ...alpha=0.7000000000000001;, score=-142024.490 total time=   0.0s
# [CV 2/30] END ....alpha=0.7000000000000001;, score=-75465.998 total time=   0.0s
# [CV 3/30] END ....alpha=0.7000000000000001;, score=-79090.420 total time=   0.0s
# [CV 4/30] END ....alpha=0.7000000000000001;, score=-88235.975 total time=   0.0s
# [CV 5/30] END ....alpha=0.7000000000000001;, score=-66766.630 total time=   0.0s
# [CV 6/30] END ....alpha=0.7000000000000001;, score=-84272.910 total time=   0.0s
# [CV 7/30] END ....alpha=0.7000000000000001;, score=-80688.892 total time=   0.0s
# [CV 8/30] END ....alpha=0.7000000000000001;, score=-71970.986 total time=   0.0s
# [CV 9/30] END ....alpha=0.7000000000000001;, score=-89813.934 total time=   0.0s
# [CV 10/30] END ...alpha=0.7000000000000001;, score=-80915.756 total time=   0.0s
# [CV 11/30] END ...alpha=0.7000000000000001;, score=-72124.600 total time=   0.0s
# [CV 12/30] END ...alpha=0.7000000000000001;, score=-86223.245 total time=   0.0s
# [CV 13/30] END ...alpha=0.7000000000000001;, score=-86850.230 total time=   0.0s
# [CV 14/30] END ...alpha=0.7000000000000001;, score=-77874.949 total time=   0.0s
# [CV 15/30] END ..alpha=0.7000000000000001;, score=-130488.855 total time=   0.0s
# [CV 16/30] END ..alpha=0.7000000000000001;, score=-100191.575 total time=   0.0s
# [CV 17/30] END ...alpha=0.7000000000000001;, score=-89891.266 total time=   0.0s
# [CV 18/30] END ...alpha=0.7000000000000001;, score=-72441.963 total time=   0.0s
# [CV 19/30] END ...alpha=0.7000000000000001;, score=-74648.554 total time=   0.0s
# [CV 20/30] END ...alpha=0.7000000000000001;, score=-72510.183 total time=   0.0s
# [CV 21/30] END ...alpha=0.7000000000000001;, score=-92722.345 total time=   0.0s
# [CV 22/30] END ...alpha=0.7000000000000001;, score=-81801.203 total time=   0.0s
# [CV 23/30] END ...alpha=0.7000000000000001;, score=-80450.823 total time=   0.0s
# [CV 24/30] END ...alpha=0.7000000000000001;, score=-93384.118 total time=   0.0s
# [CV 25/30] END ..alpha=0.7000000000000001;, score=-123915.451 total time=   0.0s
# [CV 26/30] END ...alpha=0.7000000000000001;, score=-71140.116 total time=   0.0s
# [CV 27/30] END ...alpha=0.7000000000000001;, score=-76693.054 total time=   0.0s
# [CV 28/30] END ...alpha=0.7000000000000001;, score=-80689.637 total time=   0.0s
# [CV 29/30] END ...alpha=0.7000000000000001;, score=-89973.984 total time=   0.0s
# [CV 30/30] END ...alpha=0.7000000000000001;, score=-78449.771 total time=   0.0s
# [CV 1/30] END ..................alpha=0.8;, score=-142024.423 total time=   0.0s
# [CV 2/30] END ...................alpha=0.8;, score=-75465.920 total time=   0.0s
# [CV 3/30] END ...................alpha=0.8;, score=-79090.510 total time=   0.0s
# [CV 4/30] END ...................alpha=0.8;, score=-88235.996 total time=   0.0s
# [CV 5/30] END ...................alpha=0.8;, score=-66766.560 total time=   0.0s
# [CV 6/30] END ...................alpha=0.8;, score=-84272.933 total time=   0.0s
# [CV 7/30] END ...................alpha=0.8;, score=-80688.840 total time=   0.0s
# [CV 8/30] END ...................alpha=0.8;, score=-71970.843 total time=   0.0s
# [CV 9/30] END ...................alpha=0.8;, score=-89813.833 total time=   0.0s
# [CV 10/30] END ..................alpha=0.8;, score=-80916.069 total time=   0.0s
# [CV 11/30] END ..................alpha=0.8;, score=-72124.459 total time=   0.0s
# [CV 12/30] END ..................alpha=0.8;, score=-86223.301 total time=   0.0s
# [CV 13/30] END ..................alpha=0.8;, score=-86850.224 total time=   0.0s
# [CV 14/30] END ..................alpha=0.8;, score=-77874.924 total time=   0.0s
# [CV 15/30] END .................alpha=0.8;, score=-130488.667 total time=   0.0s
# [CV 16/30] END .................alpha=0.8;, score=-100191.674 total time=   0.0s
# [CV 17/30] END ..................alpha=0.8;, score=-89891.252 total time=   0.0s
# [CV 18/30] END ..................alpha=0.8;, score=-72441.728 total time=   0.0s
# [CV 19/30] END ..................alpha=0.8;, score=-74648.561 total time=   0.0s
# [CV 20/30] END ..................alpha=0.8;, score=-72510.190 total time=   0.0s
# [CV 21/30] END ..................alpha=0.8;, score=-92722.321 total time=   0.0s
# [CV 22/30] END ..................alpha=0.8;, score=-81801.293 total time=   0.0s
# [CV 23/30] END ..................alpha=0.8;, score=-80450.838 total time=   0.0s
# [CV 24/30] END ..................alpha=0.8;, score=-93384.153 total time=   0.0s
# [CV 25/30] END .................alpha=0.8;, score=-123915.296 total time=   0.0s
# [CV 26/30] END ..................alpha=0.8;, score=-71140.031 total time=   0.0s
# [CV 27/30] END ..................alpha=0.8;, score=-76692.850 total time=   0.0s
# [CV 28/30] END ..................alpha=0.8;, score=-80689.555 total time=   0.0s
# [CV 29/30] END ..................alpha=0.8;, score=-89974.052 total time=   0.0s
# [CV 30/30] END ..................alpha=0.8;, score=-78449.774 total time=   0.0s
# [CV 1/30] END ..................alpha=0.9;, score=-142024.356 total time=   0.0s
# [CV 2/30] END ...................alpha=0.9;, score=-75465.839 total time=   0.0s
# [CV 3/30] END ...................alpha=0.9;, score=-79090.600 total time=   0.0s
# [CV 4/30] END ...................alpha=0.9;, score=-88236.018 total time=   0.0s
# [CV 5/30] END ...................alpha=0.9;, score=-66766.489 total time=   0.0s
# [CV 6/30] END ...................alpha=0.9;, score=-84272.953 total time=   0.0s
# [CV 7/30] END ...................alpha=0.9;, score=-80688.777 total time=   0.0s
# [CV 8/30] END ...................alpha=0.9;, score=-71970.707 total time=   0.0s
# [CV 9/30] END ...................alpha=0.9;, score=-89813.733 total time=   0.0s
# [CV 10/30] END ..................alpha=0.9;, score=-80916.377 total time=   0.0s
# [CV 11/30] END ..................alpha=0.9;, score=-72124.316 total time=   0.0s
# [CV 12/30] END ..................alpha=0.9;, score=-86223.358 total time=   0.0s
# [CV 13/30] END ..................alpha=0.9;, score=-86850.218 total time=   0.0s
# [CV 14/30] END ..................alpha=0.9;, score=-77874.894 total time=   0.0s
# [CV 15/30] END .................alpha=0.9;, score=-130488.479 total time=   0.0s
# [CV 16/30] END .................alpha=0.9;, score=-100191.774 total time=   0.0s
# [CV 17/30] END ..................alpha=0.9;, score=-89891.237 total time=   0.0s
# [CV 18/30] END ..................alpha=0.9;, score=-72441.493 total time=   0.0s
# [CV 19/30] END ..................alpha=0.9;, score=-74648.614 total time=   0.0s
# [CV 20/30] END ..................alpha=0.9;, score=-72510.173 total time=   0.0s
# [CV 21/30] END ..................alpha=0.9;, score=-92722.296 total time=   0.0s
# [CV 22/30] END ..................alpha=0.9;, score=-81801.382 total time=   0.0s
# [CV 23/30] END ..................alpha=0.9;, score=-80450.852 total time=   0.0s
# [CV 24/30] END ..................alpha=0.9;, score=-93384.189 total time=   0.0s
# [CV 25/30] END .................alpha=0.9;, score=-123915.140 total time=   0.0s
# [CV 26/30] END ..................alpha=0.9;, score=-71139.950 total time=   0.0s
# [CV 27/30] END ..................alpha=0.9;, score=-76692.822 total time=   0.0s
# [CV 28/30] END ..................alpha=0.9;, score=-80689.483 total time=   0.0s
# [CV 29/30] END ..................alpha=0.9;, score=-89974.121 total time=   0.0s
# [CV 30/30] END ..................alpha=0.9;, score=-78449.778 total time=   0.0s
# [CV 1/30] END ..................alpha=1.0;, score=-142024.291 total time=   0.0s
# [CV 2/30] END ...................alpha=1.0;, score=-75465.735 total time=   0.0s
# [CV 3/30] END ...................alpha=1.0;, score=-79090.690 total time=   0.0s
# [CV 4/30] END ...................alpha=1.0;, score=-88236.039 total time=   0.0s
# [CV 5/30] END ...................alpha=1.0;, score=-66766.418 total time=   0.0s
# [CV 6/30] END ...................alpha=1.0;, score=-84272.976 total time=   0.0s
# [CV 7/30] END ...................alpha=1.0;, score=-80688.703 total time=   0.0s
# [CV 8/30] END ...................alpha=1.0;, score=-71970.562 total time=   0.0s
# [CV 9/30] END ...................alpha=1.0;, score=-89813.633 total time=   0.0s
# [CV 10/30] END ..................alpha=1.0;, score=-80916.700 total time=   0.0s
# [CV 11/30] END ..................alpha=1.0;, score=-72124.172 total time=   0.0s
# [CV 12/30] END ..................alpha=1.0;, score=-86223.414 total time=   0.0s
# [CV 13/30] END ..................alpha=1.0;, score=-86850.212 total time=   0.0s
# [CV 14/30] END ..................alpha=1.0;, score=-77874.867 total time=   0.0s
# [CV 15/30] END .................alpha=1.0;, score=-130488.291 total time=   0.0s
# [CV 16/30] END .................alpha=1.0;, score=-100191.869 total time=   0.0s
# [CV 17/30] END ..................alpha=1.0;, score=-89891.222 total time=   0.0s
# [CV 18/30] END ..................alpha=1.0;, score=-72441.258 total time=   0.0s
# [CV 19/30] END ..................alpha=1.0;, score=-74648.620 total time=   0.0s
# [CV 20/30] END ..................alpha=1.0;, score=-72510.107 total time=   0.0s
# [CV 21/30] END ..................alpha=1.0;, score=-92722.270 total time=   0.0s
# [CV 22/30] END ..................alpha=1.0;, score=-81801.471 total time=   0.0s
# [CV 23/30] END ..................alpha=1.0;, score=-80450.866 total time=   0.0s
# [CV 24/30] END ..................alpha=1.0;, score=-93384.224 total time=   0.0s
# [CV 25/30] END .................alpha=1.0;, score=-123914.985 total time=   0.0s
# [CV 26/30] END ..................alpha=1.0;, score=-71139.864 total time=   0.0s
# [CV 27/30] END ..................alpha=1.0;, score=-76692.693 total time=   0.0s
# [CV 28/30] END ..................alpha=1.0;, score=-80689.332 total time=   0.0s
# [CV 29/30] END ..................alpha=1.0;, score=-89974.191 total time=   0.0s
# [CV 30/30] END ..................alpha=1.0;, score=-78449.782 total time=   0.0s
# [CV 1/30] END ..................alpha=1.1;, score=-142024.224 total time=   0.0s
# [CV 2/30] END ...................alpha=1.1;, score=-75465.652 total time=   0.0s
# [CV 3/30] END ...................alpha=1.1;, score=-79090.782 total time=   0.0s
# [CV 4/30] END ...................alpha=1.1;, score=-88236.061 total time=   0.0s
# [CV 5/30] END ...................alpha=1.1;, score=-66766.343 total time=   0.0s
# [CV 6/30] END ...................alpha=1.1;, score=-84272.998 total time=   0.0s
# [CV 7/30] END ...................alpha=1.1;, score=-80688.683 total time=   0.0s
# [CV 8/30] END ...................alpha=1.1;, score=-71970.421 total time=   0.0s
# [CV 9/30] END ...................alpha=1.1;, score=-89813.533 total time=   0.0s
# [CV 10/30] END ..................alpha=1.1;, score=-80917.008 total time=   0.0s
# [CV 11/30] END ..................alpha=1.1;, score=-72124.025 total time=   0.0s
# [CV 12/30] END ..................alpha=1.1;, score=-86223.470 total time=   0.0s
# [CV 13/30] END ..................alpha=1.1;, score=-86850.206 total time=   0.0s
# [CV 14/30] END ..................alpha=1.1;, score=-77874.840 total time=   0.0s
# [CV 15/30] END .................alpha=1.1;, score=-130488.103 total time=   0.0s
# [CV 16/30] END .................alpha=1.1;, score=-100191.972 total time=   0.0s
# [CV 17/30] END ..................alpha=1.1;, score=-89891.205 total time=   0.0s
# [CV 18/30] END ..................alpha=1.1;, score=-72441.022 total time=   0.0s
# [CV 19/30] END ..................alpha=1.1;, score=-74648.628 total time=   0.0s
# [CV 20/30] END ..................alpha=1.1;, score=-72510.089 total time=   0.0s
# [CV 21/30] END ..................alpha=1.1;, score=-92722.245 total time=   0.0s
# [CV 22/30] END ..................alpha=1.1;, score=-81801.567 total time=   0.0s
# [CV 23/30] END ..................alpha=1.1;, score=-80450.881 total time=   0.0s
# [CV 24/30] END ..................alpha=1.1;, score=-93384.260 total time=   0.0s
# [CV 25/30] END .................alpha=1.1;, score=-123914.830 total time=   0.0s
# [CV 26/30] END ..................alpha=1.1;, score=-71139.780 total time=   0.0s
# [CV 27/30] END ..................alpha=1.1;, score=-76692.477 total time=   0.0s
# [CV 28/30] END ..................alpha=1.1;, score=-80689.247 total time=   0.0s
# [CV 29/30] END ..................alpha=1.1;, score=-89974.259 total time=   0.0s
# [CV 30/30] END ..................alpha=1.1;, score=-78449.786 total time=   0.0s
# [CV 1/30] END ...alpha=1.2000000000000002;, score=-142024.159 total time=   0.0s
# [CV 2/30] END ....alpha=1.2000000000000002;, score=-75465.570 total time=   0.0s
# [CV 3/30] END ....alpha=1.2000000000000002;, score=-79090.874 total time=   0.0s
# [CV 4/30] END ....alpha=1.2000000000000002;, score=-88236.082 total time=   0.0s
# [CV 5/30] END ....alpha=1.2000000000000002;, score=-66766.275 total time=   0.0s
# [CV 6/30] END ....alpha=1.2000000000000002;, score=-84273.017 total time=   0.0s
# [CV 7/30] END ....alpha=1.2000000000000002;, score=-80688.591 total time=   0.0s
# [CV 8/30] END ....alpha=1.2000000000000002;, score=-71970.282 total time=   0.0s
# [CV 9/30] END ....alpha=1.2000000000000002;, score=-89813.433 total time=   0.0s
# [CV 10/30] END ...alpha=1.2000000000000002;, score=-80917.331 total time=   0.0s
# [CV 11/30] END ...alpha=1.2000000000000002;, score=-72123.881 total time=   0.0s
# [CV 12/30] END ...alpha=1.2000000000000002;, score=-86223.527 total time=   0.0s
# [CV 13/30] END ...alpha=1.2000000000000002;, score=-86850.200 total time=   0.0s
# [CV 14/30] END ...alpha=1.2000000000000002;, score=-77874.816 total time=   0.0s
# [CV 15/30] END ..alpha=1.2000000000000002;, score=-130487.914 total time=   0.0s
# [CV 16/30] END ..alpha=1.2000000000000002;, score=-100192.060 total time=   0.0s
# [CV 17/30] END ...alpha=1.2000000000000002;, score=-89891.189 total time=   0.0s
# [CV 18/30] END ...alpha=1.2000000000000002;, score=-72440.789 total time=   0.0s
# [CV 19/30] END ...alpha=1.2000000000000002;, score=-74648.450 total time=   0.0s
# [CV 20/30] END ...alpha=1.2000000000000002;, score=-72510.121 total time=   0.0s
# [CV 21/30] END ...alpha=1.2000000000000002;, score=-92722.220 total time=   0.0s
# [CV 22/30] END ...alpha=1.2000000000000002;, score=-81801.664 total time=   0.0s
# [CV 23/30] END ...alpha=1.2000000000000002;, score=-80450.896 total time=   0.0s
# [CV 24/30] END ...alpha=1.2000000000000002;, score=-93384.294 total time=   0.0s
# [CV 25/30] END ..alpha=1.2000000000000002;, score=-123914.677 total time=   0.0s
# [CV 26/30] END ...alpha=1.2000000000000002;, score=-71139.697 total time=   0.0s
# [CV 27/30] END ...alpha=1.2000000000000002;, score=-76692.354 total time=   0.0s
# [CV 28/30] END ...alpha=1.2000000000000002;, score=-80689.240 total time=   0.0s
# [CV 29/30] END ...alpha=1.2000000000000002;, score=-89974.328 total time=   0.0s
# [CV 30/30] END ...alpha=1.2000000000000002;, score=-78449.790 total time=   0.0s
# [CV 1/30] END ...alpha=1.3000000000000003;, score=-142024.091 total time=   0.0s
# [CV 2/30] END ....alpha=1.3000000000000003;, score=-75465.488 total time=   0.0s
# [CV 3/30] END ....alpha=1.3000000000000003;, score=-79090.962 total time=   0.0s
# [CV 4/30] END ....alpha=1.3000000000000003;, score=-88236.102 total time=   0.0s
# [CV 5/30] END ....alpha=1.3000000000000003;, score=-66766.205 total time=   0.0s
# [CV 6/30] END ....alpha=1.3000000000000003;, score=-84273.042 total time=   0.0s
# [CV 7/30] END ....alpha=1.3000000000000003;, score=-80688.543 total time=   0.0s
# [CV 8/30] END ....alpha=1.3000000000000003;, score=-71970.155 total time=   0.0s
# [CV 9/30] END ....alpha=1.3000000000000003;, score=-89813.332 total time=   0.0s
# [CV 10/30] END ...alpha=1.3000000000000003;, score=-80917.619 total time=   0.0s
# [CV 11/30] END ...alpha=1.3000000000000003;, score=-72123.740 total time=   0.0s
# [CV 12/30] END ...alpha=1.3000000000000003;, score=-86223.583 total time=   0.0s
# [CV 13/30] END ...alpha=1.3000000000000003;, score=-86850.194 total time=   0.0s
# [CV 14/30] END ...alpha=1.3000000000000003;, score=-77874.789 total time=   0.0s
# [CV 15/30] END ..alpha=1.3000000000000003;, score=-130487.729 total time=   0.0s
# [CV 16/30] END ..alpha=1.3000000000000003;, score=-100192.166 total time=   0.0s
# [CV 17/30] END ...alpha=1.3000000000000003;, score=-89891.176 total time=   0.0s
# [CV 18/30] END ...alpha=1.3000000000000003;, score=-72440.553 total time=   0.0s
# [CV 19/30] END ...alpha=1.3000000000000003;, score=-74648.676 total time=   0.0s
# [CV 20/30] END ...alpha=1.3000000000000003;, score=-72510.117 total time=   0.0s
# [CV 21/30] END ...alpha=1.3000000000000003;, score=-92722.197 total time=   0.0s
# [CV 22/30] END ...alpha=1.3000000000000003;, score=-81801.758 total time=   0.0s
# [CV 23/30] END ...alpha=1.3000000000000003;, score=-80450.910 total time=   0.0s
# [CV 24/30] END ...alpha=1.3000000000000003;, score=-93384.330 total time=   0.0s
# [CV 25/30] END ..alpha=1.3000000000000003;, score=-123914.521 total time=   0.0s
# [CV 26/30] END ...alpha=1.3000000000000003;, score=-71139.609 total time=   0.0s
# [CV 27/30] END ...alpha=1.3000000000000003;, score=-76692.360 total time=   0.0s
# [CV 28/30] END ...alpha=1.3000000000000003;, score=-80689.165 total time=   0.0s
# [CV 29/30] END ...alpha=1.3000000000000003;, score=-89974.398 total time=   0.0s
# [CV 30/30] END ...alpha=1.3000000000000003;, score=-78449.794 total time=   0.0s
# [CV 1/30] END ...alpha=1.4000000000000001;, score=-142024.027 total time=   0.0s
# [CV 2/30] END ....alpha=1.4000000000000001;, score=-75465.407 total time=   0.0s
# [CV 3/30] END ....alpha=1.4000000000000001;, score=-79091.053 total time=   0.0s
# [CV 4/30] END ....alpha=1.4000000000000001;, score=-88236.124 total time=   0.0s
# [CV 5/30] END ....alpha=1.4000000000000001;, score=-66766.139 total time=   0.0s
# [CV 6/30] END ....alpha=1.4000000000000001;, score=-84273.060 total time=   0.0s
# [CV 7/30] END ....alpha=1.4000000000000001;, score=-80688.464 total time=   0.0s
# [CV 8/30] END ....alpha=1.4000000000000001;, score=-71970.004 total time=   0.0s
# [CV 9/30] END ....alpha=1.4000000000000001;, score=-89813.233 total time=   0.0s
# [CV 10/30] END ...alpha=1.4000000000000001;, score=-80917.947 total time=   0.0s
# [CV 11/30] END ...alpha=1.4000000000000001;, score=-72123.602 total time=   0.0s
# [CV 12/30] END ...alpha=1.4000000000000001;, score=-86223.639 total time=   0.0s
# [CV 13/30] END ...alpha=1.4000000000000001;, score=-86850.188 total time=   0.0s
# [CV 14/30] END ...alpha=1.4000000000000001;, score=-77874.760 total time=   0.0s
# [CV 15/30] END ..alpha=1.4000000000000001;, score=-130487.540 total time=   0.0s
# [CV 16/30] END ..alpha=1.4000000000000001;, score=-100192.266 total time=   0.0s
# [CV 17/30] END ...alpha=1.4000000000000001;, score=-89891.161 total time=   0.0s
# [CV 18/30] END ...alpha=1.4000000000000001;, score=-72440.316 total time=   0.0s
# [CV 19/30] END ...alpha=1.4000000000000001;, score=-74648.683 total time=   0.0s
# [CV 20/30] END ...alpha=1.4000000000000001;, score=-72510.061 total time=   0.0s
# [CV 21/30] END ...alpha=1.4000000000000001;, score=-92722.172 total time=   0.0s
# [CV 22/30] END ...alpha=1.4000000000000001;, score=-81801.845 total time=   0.0s
# [CV 23/30] END ...alpha=1.4000000000000001;, score=-80450.925 total time=   0.0s
# [CV 24/30] END ...alpha=1.4000000000000001;, score=-93384.365 total time=   0.0s
# [CV 25/30] END ..alpha=1.4000000000000001;, score=-123914.365 total time=   0.0s
# [CV 26/30] END ...alpha=1.4000000000000001;, score=-71139.531 total time=   0.0s
# [CV 27/30] END ...alpha=1.4000000000000001;, score=-76692.244 total time=   0.0s
# [CV 28/30] END ...alpha=1.4000000000000001;, score=-80689.099 total time=   0.0s
# [CV 29/30] END ...alpha=1.4000000000000001;, score=-89974.500 total time=   0.0s
# [CV 30/30] END ...alpha=1.4000000000000001;, score=-78449.798 total time=   0.0s
# [CV 1/30] END ...alpha=1.5000000000000002;, score=-142023.957 total time=   0.0s
# [CV 2/30] END ....alpha=1.5000000000000002;, score=-75465.325 total time=   0.0s
# [CV 3/30] END ....alpha=1.5000000000000002;, score=-79091.150 total time=   0.0s
# [CV 4/30] END ....alpha=1.5000000000000002;, score=-88236.144 total time=   0.0s
# [CV 5/30] END ....alpha=1.5000000000000002;, score=-66766.062 total time=   0.0s
# [CV 6/30] END ....alpha=1.5000000000000002;, score=-84273.085 total time=   0.0s
# [CV 7/30] END ....alpha=1.5000000000000002;, score=-80688.434 total time=   0.0s
# [CV 8/30] END ....alpha=1.5000000000000002;, score=-71969.861 total time=   0.0s
# [CV 9/30] END ....alpha=1.5000000000000002;, score=-89813.131 total time=   0.0s
# [CV 10/30] END ...alpha=1.5000000000000002;, score=-80918.243 total time=   0.0s
# [CV 11/30] END ...alpha=1.5000000000000002;, score=-72123.454 total time=   0.0s
# [CV 12/30] END ...alpha=1.5000000000000002;, score=-86223.696 total time=   0.0s
# [CV 13/30] END ...alpha=1.5000000000000002;, score=-86850.182 total time=   0.0s
# [CV 14/30] END ...alpha=1.5000000000000002;, score=-77874.732 total time=   0.0s
# [CV 15/30] END ..alpha=1.5000000000000002;, score=-130487.350 total time=   0.0s
# [CV 16/30] END ..alpha=1.5000000000000002;, score=-100192.363 total time=   0.0s
# [CV 17/30] END ...alpha=1.5000000000000002;, score=-89891.145 total time=   0.0s
# [CV 18/30] END ...alpha=1.5000000000000002;, score=-72440.084 total time=   0.0s
# [CV 19/30] END ...alpha=1.5000000000000002;, score=-74648.741 total time=   0.0s
# [CV 20/30] END ...alpha=1.5000000000000002;, score=-72509.961 total time=   0.0s
# [CV 21/30] END ...alpha=1.5000000000000002;, score=-92722.151 total time=   0.0s
# [CV 22/30] END ...alpha=1.5000000000000002;, score=-81801.936 total time=   0.0s
# [CV 23/30] END ...alpha=1.5000000000000002;, score=-80450.939 total time=   0.0s
# [CV 24/30] END ...alpha=1.5000000000000002;, score=-93384.401 total time=   0.0s
# [CV 25/30] END ..alpha=1.5000000000000002;, score=-123914.209 total time=   0.0s
# [CV 26/30] END ...alpha=1.5000000000000002;, score=-71139.446 total time=   0.0s
# [CV 27/30] END ...alpha=1.5000000000000002;, score=-76692.150 total time=   0.0s
# [CV 28/30] END ...alpha=1.5000000000000002;, score=-80689.009 total time=   0.0s
# [CV 29/30] END ...alpha=1.5000000000000002;, score=-89974.536 total time=   0.0s
# [CV 30/30] END ...alpha=1.5000000000000002;, score=-78449.801 total time=   0.0s
# [CV 1/30] END ..................alpha=1.6;, score=-142023.892 total time=   0.0s
# [CV 2/30] END ...................alpha=1.6;, score=-75465.241 total time=   0.0s
# [CV 3/30] END ...................alpha=1.6;, score=-79091.237 total time=   0.0s
# [CV 4/30] END ...................alpha=1.6;, score=-88236.165 total time=   0.0s
# [CV 5/30] END ...................alpha=1.6;, score=-66765.991 total time=   0.0s
# [CV 6/30] END ...................alpha=1.6;, score=-84273.108 total time=   0.0s
# [CV 7/30] END ...................alpha=1.6;, score=-80688.347 total time=   0.0s
# [CV 8/30] END ...................alpha=1.6;, score=-71969.732 total time=   0.0s
# [CV 9/30] END ...................alpha=1.6;, score=-89813.032 total time=   0.0s
# [CV 10/30] END ..................alpha=1.6;, score=-80918.574 total time=   0.0s
# [CV 11/30] END ..................alpha=1.6;, score=-72123.309 total time=   0.0s
# [CV 12/30] END ..................alpha=1.6;, score=-86223.752 total time=   0.0s
# [CV 13/30] END ..................alpha=1.6;, score=-86850.176 total time=   0.0s
# [CV 14/30] END ..................alpha=1.6;, score=-77874.704 total time=   0.0s
# [CV 15/30] END .................alpha=1.6;, score=-130487.165 total time=   0.0s
# [CV 16/30] END .................alpha=1.6;, score=-100192.464 total time=   0.0s
# [CV 17/30] END ..................alpha=1.6;, score=-89891.133 total time=   0.0s
# [CV 18/30] END ..................alpha=1.6;, score=-72439.847 total time=   0.0s
# [CV 19/30] END ..................alpha=1.6;, score=-74648.754 total time=   0.0s
# [CV 20/30] END ..................alpha=1.6;, score=-72509.955 total time=   0.0s
# [CV 21/30] END ..................alpha=1.6;, score=-92722.126 total time=   0.0s
# [CV 22/30] END ..................alpha=1.6;, score=-81802.036 total time=   0.0s
# [CV 23/30] END ..................alpha=1.6;, score=-80450.951 total time=   0.0s
# [CV 24/30] END ..................alpha=1.6;, score=-93384.437 total time=   0.0s
# [CV 25/30] END .................alpha=1.6;, score=-123914.058 total time=   0.0s
# [CV 26/30] END ..................alpha=1.6;, score=-71139.362 total time=   0.0s
# [CV 27/30] END ..................alpha=1.6;, score=-76691.859 total time=   0.0s
# [CV 28/30] END ..................alpha=1.6;, score=-80688.941 total time=   0.0s
# [CV 29/30] END ..................alpha=1.6;, score=-89974.605 total time=   0.0s
# [CV 30/30] END ..................alpha=1.6;, score=-78449.805 total time=   0.0s
# [CV 1/30] END ...alpha=1.7000000000000002;, score=-142023.827 total time=   0.0s
# [CV 2/30] END ....alpha=1.7000000000000002;, score=-75465.156 total time=   0.0s
# [CV 3/30] END ....alpha=1.7000000000000002;, score=-79091.325 total time=   0.0s
# [CV 4/30] END ....alpha=1.7000000000000002;, score=-88236.188 total time=   0.0s
# [CV 5/30] END ....alpha=1.7000000000000002;, score=-66765.917 total time=   0.0s
# [CV 6/30] END ....alpha=1.7000000000000002;, score=-84273.125 total time=   0.0s
# [CV 7/30] END ....alpha=1.7000000000000002;, score=-80688.299 total time=   0.0s
# [CV 8/30] END ....alpha=1.7000000000000002;, score=-71969.588 total time=   0.0s
# [CV 9/30] END ....alpha=1.7000000000000002;, score=-89812.931 total time=   0.0s
# [CV 10/30] END ...alpha=1.7000000000000002;, score=-80918.894 total time=   0.0s
# [CV 11/30] END ...alpha=1.7000000000000002;, score=-72123.172 total time=   0.0s
# [CV 12/30] END ...alpha=1.7000000000000002;, score=-86223.809 total time=   0.0s
# [CV 13/30] END ...alpha=1.7000000000000002;, score=-86850.170 total time=   0.0s
# [CV 14/30] END ...alpha=1.7000000000000002;, score=-77874.679 total time=   0.0s
# [CV 15/30] END ..alpha=1.7000000000000002;, score=-130486.974 total time=   0.0s
# [CV 16/30] END ..alpha=1.7000000000000002;, score=-100192.563 total time=   0.0s
# [CV 17/30] END ...alpha=1.7000000000000002;, score=-89891.117 total time=   0.0s
# [CV 18/30] END ...alpha=1.7000000000000002;, score=-72439.614 total time=   0.0s
# [CV 19/30] END ...alpha=1.7000000000000002;, score=-74648.744 total time=   0.0s
# [CV 20/30] END ...alpha=1.7000000000000002;, score=-72509.925 total time=   0.0s
# [CV 21/30] END ...alpha=1.7000000000000002;, score=-92722.101 total time=   0.0s
# [CV 22/30] END ...alpha=1.7000000000000002;, score=-81802.121 total time=   0.0s
# [CV 23/30] END ...alpha=1.7000000000000002;, score=-80450.965 total time=   0.0s
# [CV 24/30] END ...alpha=1.7000000000000002;, score=-93384.472 total time=   0.0s
# [CV 25/30] END ..alpha=1.7000000000000002;, score=-123913.901 total time=   0.0s
# [CV 26/30] END ...alpha=1.7000000000000002;, score=-71139.273 total time=   0.0s
# [CV 27/30] END ...alpha=1.7000000000000002;, score=-76691.926 total time=   0.0s
# [CV 28/30] END ...alpha=1.7000000000000002;, score=-80688.856 total time=   0.0s
# [CV 29/30] END ...alpha=1.7000000000000002;, score=-89974.675 total time=   0.0s
# [CV 30/30] END ...alpha=1.7000000000000002;, score=-78449.809 total time=   0.0s
# [CV 1/30] END ...alpha=1.8000000000000003;, score=-142023.760 total time=   0.0s
# [CV 2/30] END ....alpha=1.8000000000000003;, score=-75465.073 total time=   0.0s
# [CV 3/30] END ....alpha=1.8000000000000003;, score=-79091.422 total time=   0.0s
# [CV 4/30] END ....alpha=1.8000000000000003;, score=-88236.207 total time=   0.0s
# [CV 5/30] END ....alpha=1.8000000000000003;, score=-66765.849 total time=   0.0s
# [CV 6/30] END ....alpha=1.8000000000000003;, score=-84273.146 total time=   0.0s
# [CV 7/30] END ....alpha=1.8000000000000003;, score=-80688.225 total time=   0.0s
# [CV 8/30] END ....alpha=1.8000000000000003;, score=-71969.456 total time=   0.0s
# [CV 9/30] END ....alpha=1.8000000000000003;, score=-89812.832 total time=   0.0s
# [CV 10/30] END ...alpha=1.8000000000000003;, score=-80919.195 total time=   0.0s
# [CV 11/30] END ...alpha=1.8000000000000003;, score=-72123.023 total time=   0.0s
# [CV 12/30] END ...alpha=1.8000000000000003;, score=-86223.865 total time=   0.0s
# [CV 13/30] END ...alpha=1.8000000000000003;, score=-86850.164 total time=   0.0s
# [CV 14/30] END ...alpha=1.8000000000000003;, score=-77874.650 total time=   0.0s
# [CV 15/30] END ..alpha=1.8000000000000003;, score=-130486.789 total time=   0.0s
# [CV 16/30] END ..alpha=1.8000000000000003;, score=-100192.652 total time=   0.0s
# [CV 17/30] END ...alpha=1.8000000000000003;, score=-89891.100 total time=   0.0s
# [CV 18/30] END ...alpha=1.8000000000000003;, score=-72439.376 total time=   0.0s
# [CV 19/30] END ...alpha=1.8000000000000003;, score=-74648.780 total time=   0.0s
# [CV 20/30] END ...alpha=1.8000000000000003;, score=-72510.019 total time=   0.0s
# [CV 21/30] END ...alpha=1.8000000000000003;, score=-92722.077 total time=   0.0s
# [CV 22/30] END ...alpha=1.8000000000000003;, score=-81802.206 total time=   0.0s
# [CV 23/30] END ...alpha=1.8000000000000003;, score=-80450.980 total time=   0.0s
# [CV 24/30] END ...alpha=1.8000000000000003;, score=-93384.507 total time=   0.0s
# [CV 25/30] END ..alpha=1.8000000000000003;, score=-123913.744 total time=   0.0s
# [CV 26/30] END ...alpha=1.8000000000000003;, score=-71139.191 total time=   0.0s
# [CV 27/30] END ...alpha=1.8000000000000003;, score=-76691.783 total time=   0.0s
# [CV 28/30] END ...alpha=1.8000000000000003;, score=-80688.792 total time=   0.0s
# [CV 29/30] END ...alpha=1.8000000000000003;, score=-89974.743 total time=   0.0s
# [CV 30/30] END ...alpha=1.8000000000000003;, score=-78449.813 total time=   0.0s
# [CV 1/30] END ...alpha=1.9000000000000001;, score=-142023.699 total time=   0.0s
# [CV 2/30] END ....alpha=1.9000000000000001;, score=-75464.991 total time=   0.0s
# [CV 3/30] END ....alpha=1.9000000000000001;, score=-79091.509 total time=   0.0s
# [CV 4/30] END ....alpha=1.9000000000000001;, score=-88236.228 total time=   0.0s
# [CV 5/30] END ....alpha=1.9000000000000001;, score=-66765.780 total time=   0.0s
# [CV 6/30] END ....alpha=1.9000000000000001;, score=-84273.171 total time=   0.0s
# [CV 7/30] END ....alpha=1.9000000000000001;, score=-80688.195 total time=   0.0s
# [CV 8/30] END ....alpha=1.9000000000000001;, score=-71969.316 total time=   0.0s
# [CV 9/30] END ....alpha=1.9000000000000001;, score=-89812.732 total time=   0.0s
# [CV 10/30] END ...alpha=1.9000000000000001;, score=-80919.484 total time=   0.0s
# [CV 11/30] END ...alpha=1.9000000000000001;, score=-72122.881 total time=   0.0s
# [CV 12/30] END ...alpha=1.9000000000000001;, score=-86223.922 total time=   0.0s
# [CV 13/30] END ...alpha=1.9000000000000001;, score=-86850.158 total time=   0.0s
# [CV 14/30] END ...alpha=1.9000000000000001;, score=-77874.625 total time=   0.0s
# [CV 15/30] END ..alpha=1.9000000000000001;, score=-130486.598 total time=   0.0s
# [CV 16/30] END ..alpha=1.9000000000000001;, score=-100192.748 total time=   0.0s
# [CV 17/30] END ...alpha=1.9000000000000001;, score=-89891.084 total time=   0.0s
# [CV 18/30] END ...alpha=1.9000000000000001;, score=-72439.144 total time=   0.0s
# [CV 19/30] END ...alpha=1.9000000000000001;, score=-74648.474 total time=   0.0s
# [CV 20/30] END ...alpha=1.9000000000000001;, score=-72510.014 total time=   0.0s
# [CV 21/30] END ...alpha=1.9000000000000001;, score=-92722.053 total time=   0.0s
# [CV 22/30] END ...alpha=1.9000000000000001;, score=-81802.304 total time=   0.0s
# [CV 23/30] END ...alpha=1.9000000000000001;, score=-80451.613 total time=   0.0s
# [CV 24/30] END ...alpha=1.9000000000000001;, score=-93384.542 total time=   0.0s
# [CV 25/30] END ..alpha=1.9000000000000001;, score=-123913.589 total time=   0.0s
# [CV 26/30] END ...alpha=1.9000000000000001;, score=-71139.115 total time=   0.0s
# [CV 27/30] END ...alpha=1.9000000000000001;, score=-76691.699 total time=   0.0s
# [CV 28/30] END ...alpha=1.9000000000000001;, score=-80688.564 total time=   0.0s
# [CV 29/30] END ...alpha=1.9000000000000001;, score=-89974.811 total time=   0.0s
# [CV 30/30] END ...alpha=1.9000000000000001;, score=-78449.816 total time=   0.0s
# [CV 1/30] END ..................alpha=2.0;, score=-142023.629 total time=   0.0s
# [CV 2/30] END ...................alpha=2.0;, score=-75464.909 total time=   0.0s
# [CV 3/30] END ...................alpha=2.0;, score=-79091.599 total time=   0.0s
# [CV 4/30] END ...................alpha=2.0;, score=-88236.252 total time=   0.0s
# [CV 5/30] END ...................alpha=2.0;, score=-66765.707 total time=   0.0s
# [CV 6/30] END ...................alpha=2.0;, score=-84273.191 total time=   0.0s
# [CV 7/30] END ...................alpha=2.0;, score=-80688.173 total time=   0.0s
# [CV 8/30] END ...................alpha=2.0;, score=-71969.160 total time=   0.0s
# [CV 9/30] END ...................alpha=2.0;, score=-89812.630 total time=   0.0s
# [CV 10/30] END ..................alpha=2.0;, score=-80919.807 total time=   0.0s
# [CV 11/30] END ..................alpha=2.0;, score=-72122.742 total time=   0.0s
# [CV 12/30] END ..................alpha=2.0;, score=-86223.978 total time=   0.0s
# [CV 13/30] END ..................alpha=2.0;, score=-86850.152 total time=   0.0s
# [CV 14/30] END ..................alpha=2.0;, score=-77874.591 total time=   0.0s
# [CV 15/30] END .................alpha=2.0;, score=-130486.413 total time=   0.0s
# [CV 16/30] END .................alpha=2.0;, score=-100192.846 total time=   0.0s
# [CV 17/30] END ..................alpha=2.0;, score=-89891.066 total time=   0.0s
# [CV 18/30] END ..................alpha=2.0;, score=-72438.906 total time=   0.0s
# [CV 19/30] END ..................alpha=2.0;, score=-74648.806 total time=   0.0s
# [CV 20/30] END ..................alpha=2.0;, score=-72509.932 total time=   0.0s
# [CV 21/30] END ..................alpha=2.0;, score=-92722.027 total time=   0.0s
# ...
# [CV 16/30] END .................alpha=4.3;, score=-100195.235 total time=   0.0s
# [CV 17/30] END ..................alpha=4.3;, score=-89890.715 total time=   0.0s
# [CV 18/30] END ..................alpha=4.3;, score=-72434.458 total time=   0.0s
# [CV 19/30] END ..................alpha=4.3;, score=-74648.562 total time=   0.0s
# [CV 20/30] END ..................alpha=4.3;, score=-72509.273 total time=   0.0s
# [CV 21/30] END ..................alpha=4.3;, score=-92721.464 total time=   0.0s
# [CV 22/30] END ..................alpha=4.3;, score=-81804.528 total time=   0.0s
# [CV 23/30] END ..................alpha=4.3;, score=-80452.889 total time=   0.0s
# [CV 24/30] END ..................alpha=4.3;, score=-93385.395 total time=   0.0s
# [CV 25/30] END .................alpha=4.3;, score=-123909.845 total time=   0.0s
# [CV 26/30] END ..................alpha=4.3;, score=-71137.110 total time=   0.0s
# [CV 27/30] END ..................alpha=4.3;, score=-76689.001 total time=   0.0s
# [CV 28/30] END ..................alpha=4.3;, score=-80686.857 total time=   0.0s
# [CV 29/30] END ..................alpha=4.3;, score=-89976.469 total time=   0.0s
# [CV 30/30] END ..................alpha=4.3;, score=-78449.914 total time=   0.0s
# [CV 1/30] END ...alpha=4.3999999999999995;, score=-142022.048 total time=   0.0s
# [CV 2/30] END ....alpha=4.3999999999999995;, score=-75462.947 total time=   0.0s
# [CV 3/30] END ....alpha=4.3999999999999995;, score=-79093.790 total time=   0.0s
# [CV 4/30] END ....alpha=4.3999999999999995;, score=-88236.779 total time=   0.0s
# [CV 5/30] END ....alpha=4.3999999999999995;, score=-66764.042 total time=   0.0s
# [CV 6/30] END ....alpha=4.3999999999999995;, score=-84273.715 total time=   0.0s
# [CV 7/30] END ....alpha=4.3999999999999995;, score=-80686.742 total time=   0.0s
# [CV 8/30] END ....alpha=4.3999999999999995;, score=-71965.841 total time=   0.0s
# [CV 9/30] END ....alpha=4.3999999999999995;, score=-89810.234 total time=   0.0s
# [CV 10/30] END ...alpha=4.3999999999999995;, score=-80927.346 total time=   0.0s
# [CV 11/30] END ...alpha=4.3999999999999995;, score=-72119.308 total time=   0.0s
# [CV 12/30] END ...alpha=4.3999999999999995;, score=-86225.336 total time=   0.0s
# [CV 13/30] END ...alpha=4.3999999999999995;, score=-86850.012 total time=   0.0s
# [CV 14/30] END ...alpha=4.3999999999999995;, score=-77873.933 total time=   0.0s
# [CV 15/30] END ..alpha=4.3999999999999995;, score=-130481.905 total time=   0.0s
# [CV 16/30] END ..alpha=4.3999999999999995;, score=-100195.268 total time=   0.0s
# [CV 17/30] END ...alpha=4.3999999999999995;, score=-89890.702 total time=   0.0s
# [CV 18/30] END ...alpha=4.3999999999999995;, score=-72434.236 total time=   0.0s
# [CV 19/30] END ...alpha=4.3999999999999995;, score=-74649.369 total time=   0.0s
# [CV 20/30] END ...alpha=4.3999999999999995;, score=-72509.526 total time=   0.0s
# [CV 21/30] END ...alpha=4.3999999999999995;, score=-92721.434 total time=   0.0s
# [CV 22/30] END ...alpha=4.3999999999999995;, score=-81804.637 total time=   0.0s
# [CV 23/30] END ...alpha=4.3999999999999995;, score=-80452.938 total time=   0.0s
# [CV 24/30] END ...alpha=4.3999999999999995;, score=-93385.430 total time=   0.0s
# [CV 25/30] END ..alpha=4.3999999999999995;, score=-123909.677 total time=   0.0s
# [CV 26/30] END ...alpha=4.3999999999999995;, score=-71137.025 total time=   0.0s
# [CV 27/30] END ...alpha=4.3999999999999995;, score=-76688.879 total time=   0.0s
# [CV 28/30] END ...alpha=4.3999999999999995;, score=-80686.788 total time=   0.0s
# [CV 29/30] END ...alpha=4.3999999999999995;, score=-89976.537 total time=   0.0s
# [CV 30/30] END ...alpha=4.3999999999999995;, score=-78449.918 total time=   0.0s
# [CV 1/30] END ..................alpha=4.5;, score=-142021.968 total time=   0.0s
# [CV 2/30] END ...................alpha=4.5;, score=-75462.865 total time=   0.0s
# [CV 3/30] END ...................alpha=4.5;, score=-79093.880 total time=   0.0s
# [CV 4/30] END ...................alpha=4.5;, score=-88236.809 total time=   0.0s
# [CV 5/30] END ...................alpha=4.5;, score=-66763.933 total time=   0.0s
# [CV 6/30] END ...................alpha=4.5;, score=-84273.734 total time=   0.0s
# [CV 7/30] END ...................alpha=4.5;, score=-80686.721 total time=   0.0s
# [CV 8/30] END ...................alpha=4.5;, score=-71965.699 total time=   0.0s
# [CV 9/30] END ...................alpha=4.5;, score=-89810.127 total time=   0.0s
# [CV 10/30] END ..................alpha=4.5;, score=-80927.578 total time=   0.0s
# [CV 11/30] END ..................alpha=4.5;, score=-72119.175 total time=   0.0s
# [CV 12/30] END ..................alpha=4.5;, score=-86225.392 total time=   0.0s
# [CV 13/30] END ..................alpha=4.5;, score=-86850.007 total time=   0.0s
# [CV 14/30] END ..................alpha=4.5;, score=-77873.900 total time=   0.0s
# [CV 15/30] END .................alpha=4.5;, score=-130481.721 total time=   0.0s
# [CV 16/30] END .................alpha=4.5;, score=-100195.352 total time=   0.0s
# [CV 17/30] END ..................alpha=4.5;, score=-89890.692 total time=   0.0s
# [CV 18/30] END ..................alpha=4.5;, score=-72434.026 total time=   0.0s
# [CV 19/30] END ..................alpha=4.5;, score=-74649.388 total time=   0.0s
# [CV 20/30] END ..................alpha=4.5;, score=-72509.444 total time=   0.0s
# [CV 21/30] END ..................alpha=4.5;, score=-92721.414 total time=   0.0s
# [CV 22/30] END ..................alpha=4.5;, score=-81804.712 total time=   0.0s
# [CV 23/30] END ..................alpha=4.5;, score=-80452.989 total time=   0.0s
# [CV 24/30] END ..................alpha=4.5;, score=-93385.465 total time=   0.0s
# [CV 25/30] END .................alpha=4.5;, score=-123909.509 total time=   0.0s
# [CV 26/30] END ..................alpha=4.5;, score=-71136.931 total time=   0.0s
# [CV 27/30] END ..................alpha=4.5;, score=-76688.277 total time=   0.0s
# [CV 28/30] END ..................alpha=4.5;, score=-80686.645 total time=   0.0s
# [CV 29/30] END ..................alpha=4.5;, score=-89976.608 total time=   0.0s
# [CV 30/30] END ..................alpha=4.5;, score=-78449.923 total time=   0.0s
# [CV 1/30] END ..................alpha=4.6;, score=-142021.908 total time=   0.0s
# [CV 2/30] END ...................alpha=4.6;, score=-75462.784 total time=   0.0s
# [CV 3/30] END ...................alpha=4.6;, score=-79093.952 total time=   0.0s
# [CV 4/30] END ...................alpha=4.6;, score=-88236.831 total time=   0.0s
# [CV 5/30] END ...................alpha=4.6;, score=-66763.871 total time=   0.0s
# [CV 6/30] END ...................alpha=4.6;, score=-84273.754 total time=   0.0s
# [CV 7/30] END ...................alpha=4.6;, score=-80686.555 total time=   0.0s
# [CV 8/30] END ...................alpha=4.6;, score=-71965.537 total time=   0.0s
# [CV 9/30] END ...................alpha=4.6;, score=-89810.033 total time=   0.0s
# [CV 10/30] END ..................alpha=4.6;, score=-80927.929 total time=   0.0s
# [CV 11/30] END ..................alpha=4.6;, score=-72119.035 total time=   0.0s
# [CV 12/30] END ..................alpha=4.6;, score=-86225.449 total time=   0.0s
# [CV 13/30] END ..................alpha=4.6;, score=-86850.001 total time=   0.0s
# [CV 14/30] END ..................alpha=4.6;, score=-77873.885 total time=   0.0s
# [CV 15/30] END .................alpha=4.6;, score=-130481.536 total time=   0.0s
# [CV 16/30] END .................alpha=4.6;, score=-100195.416 total time=   0.0s
# [CV 17/30] END ..................alpha=4.6;, score=-89890.686 total time=   0.0s
# [CV 18/30] END ..................alpha=4.6;, score=-72433.817 total time=   0.0s
# [CV 19/30] END ..................alpha=4.6;, score=-74648.569 total time=   0.0s
# [CV 20/30] END ..................alpha=4.6;, score=-72509.571 total time=   0.0s
# [CV 21/30] END ..................alpha=4.6;, score=-92721.389 total time=   0.0s
# [CV 22/30] END ..................alpha=4.6;, score=-81804.802 total time=   0.0s
# [CV 23/30] END ..................alpha=4.6;, score=-80453.040 total time=   0.0s
# [CV 24/30] END ..................alpha=4.6;, score=-93385.501 total time=   0.0s
# [CV 25/30] END .................alpha=4.6;, score=-123909.338 total time=   0.0s
# [CV 26/30] END ..................alpha=4.6;, score=-71136.860 total time=   0.0s
# [CV 27/30] END ..................alpha=4.6;, score=-76688.601 total time=   0.0s
# [CV 28/30] END ..................alpha=4.6;, score=-80686.626 total time=   0.0s
# [CV 29/30] END ..................alpha=4.6;, score=-89976.676 total time=   0.0s
# [CV 30/30] END ..................alpha=4.6;, score=-78449.930 total time=   0.0s
# [CV 1/30] END ..................alpha=4.7;, score=-142021.851 total time=   0.0s
# [CV 2/30] END ...................alpha=4.7;, score=-75462.703 total time=   0.0s
# [CV 3/30] END ...................alpha=4.7;, score=-79094.049 total time=   0.0s
# [CV 4/30] END ...................alpha=4.7;, score=-88236.862 total time=   0.0s
# [CV 5/30] END ...................alpha=4.7;, score=-66763.814 total time=   0.0s
# [CV 6/30] END ...................alpha=4.7;, score=-84273.776 total time=   0.0s
# [CV 7/30] END ...................alpha=4.7;, score=-80686.281 total time=   0.0s
# [CV 8/30] END ...................alpha=4.7;, score=-71965.413 total time=   0.0s
# [CV 9/30] END ...................alpha=4.7;, score=-89809.931 total time=   0.0s
# [CV 10/30] END ..................alpha=4.7;, score=-80928.216 total time=   0.0s
# [CV 11/30] END ..................alpha=4.7;, score=-72118.890 total time=   0.0s
# [CV 12/30] END ..................alpha=4.7;, score=-86225.506 total time=   0.0s
# [CV 13/30] END ..................alpha=4.7;, score=-86849.995 total time=   0.0s
# [CV 14/30] END ..................alpha=4.7;, score=-77873.862 total time=   0.0s
# [CV 15/30] END .................alpha=4.7;, score=-130481.352 total time=   0.0s
# [CV 16/30] END .................alpha=4.7;, score=-100195.510 total time=   0.0s
# [CV 17/30] END ..................alpha=4.7;, score=-89890.666 total time=   0.0s
# [CV 18/30] END ..................alpha=4.7;, score=-72433.607 total time=   0.0s
# [CV 19/30] END ..................alpha=4.7;, score=-74649.431 total time=   0.0s
# [CV 20/30] END ..................alpha=4.7;, score=-72509.294 total time=   0.0s
# [CV 21/30] END ..................alpha=4.7;, score=-92721.358 total time=   0.0s
# [CV 22/30] END ..................alpha=4.7;, score=-81804.899 total time=   0.0s
# [CV 23/30] END ..................alpha=4.7;, score=-80453.091 total time=   0.0s
# [CV 24/30] END ..................alpha=4.7;, score=-93385.538 total time=   0.0s
# [CV 25/30] END .................alpha=4.7;, score=-123909.166 total time=   0.0s
# [CV 26/30] END ..................alpha=4.7;, score=-71136.781 total time=   0.0s
# [CV 27/30] END ..................alpha=4.7;, score=-76688.035 total time=   0.0s
# [CV 28/30] END ..................alpha=4.7;, score=-80686.528 total time=   0.0s
# [CV 29/30] END ..................alpha=4.7;, score=-89976.747 total time=   0.0s
# [CV 30/30] END ..................alpha=4.7;, score=-78449.930 total time=   0.0s
# [CV 1/30] END ..................alpha=4.8;, score=-142021.775 total time=   0.0s
# [CV 2/30] END ...................alpha=4.8;, score=-75462.621 total time=   0.0s
# [CV 3/30] END ...................alpha=4.8;, score=-79094.150 total time=   0.0s
# [CV 4/30] END ...................alpha=4.8;, score=-88236.894 total time=   0.0s
# [CV 5/30] END ...................alpha=4.8;, score=-66763.718 total time=   0.0s
# [CV 6/30] END ...................alpha=4.8;, score=-84273.799 total time=   0.0s
# [CV 7/30] END ...................alpha=4.8;, score=-80686.217 total time=   0.0s
# [CV 8/30] END ...................alpha=4.8;, score=-71965.272 total time=   0.0s
# [CV 9/30] END ...................alpha=4.8;, score=-89809.831 total time=   0.0s
# [CV 10/30] END ..................alpha=4.8;, score=-80928.528 total time=   0.0s
# [CV 11/30] END ..................alpha=4.8;, score=-72118.737 total time=   0.0s
# [CV 12/30] END ..................alpha=4.8;, score=-86225.563 total time=   0.0s
# [CV 13/30] END ..................alpha=4.8;, score=-86849.990 total time=   0.0s
# [CV 14/30] END ..................alpha=4.8;, score=-77873.834 total time=   0.0s
# [CV 15/30] END .................alpha=4.8;, score=-130481.150 total time=   0.0s
# [CV 16/30] END .................alpha=4.8;, score=-100195.605 total time=   0.0s
# [CV 17/30] END ..................alpha=4.8;, score=-89890.649 total time=   0.0s
# [CV 18/30] END ..................alpha=4.8;, score=-72433.397 total time=   0.0s
# [CV 19/30] END ..................alpha=4.8;, score=-74649.445 total time=   0.0s
# [CV 20/30] END ..................alpha=4.8;, score=-72509.208 total time=   0.0s
# [CV 21/30] END ..................alpha=4.8;, score=-92721.340 total time=   0.0s
# [CV 22/30] END ..................alpha=4.8;, score=-81805.015 total time=   0.0s
# [CV 23/30] END ..................alpha=4.8;, score=-80453.143 total time=   0.0s
# [CV 24/30] END ..................alpha=4.8;, score=-93385.572 total time=   0.0s
# [CV 25/30] END .................alpha=4.8;, score=-123908.990 total time=   0.0s
# [CV 26/30] END ..................alpha=4.8;, score=-71136.692 total time=   0.0s
# [CV 27/30] END ..................alpha=4.8;, score=-76687.909 total time=   0.0s
# [CV 28/30] END ..................alpha=4.8;, score=-80686.454 total time=   0.0s
# [CV 29/30] END ..................alpha=4.8;, score=-89976.813 total time=   0.0s
# [CV 30/30] END ..................alpha=4.8;, score=-78449.931 total time=   0.0s
# [CV 1/30] END ..................alpha=4.9;, score=-142021.702 total time=   0.0s
# [CV 2/30] END ...................alpha=4.9;, score=-75462.539 total time=   0.0s
# [CV 3/30] END ...................alpha=4.9;, score=-79094.232 total time=   0.0s
# [CV 4/30] END ...................alpha=4.9;, score=-88236.928 total time=   0.0s
# [CV 5/30] END ...................alpha=4.9;, score=-66763.671 total time=   0.0s
# [CV 6/30] END ...................alpha=4.9;, score=-84273.781 total time=   0.0s
# [CV 7/30] END ...................alpha=4.9;, score=-80686.373 total time=   0.0s
# [CV 8/30] END ...................alpha=4.9;, score=-71965.113 total time=   0.0s
# [CV 9/30] END ...................alpha=4.9;, score=-89809.734 total time=   0.0s
# [CV 10/30] END ..................alpha=4.9;, score=-80928.863 total time=   0.0s
# [CV 11/30] END ..................alpha=4.9;, score=-72118.605 total time=   0.0s
# [CV 12/30] END ..................alpha=4.9;, score=-86225.619 total time=   0.0s
# [CV 13/30] END ..................alpha=4.9;, score=-86849.985 total time=   0.0s
# [CV 14/30] END ..................alpha=4.9;, score=-77873.800 total time=   0.0s
# [CV 15/30] END .................alpha=4.9;, score=-130480.966 total time=   0.0s
# [CV 16/30] END .................alpha=4.9;, score=-100195.700 total time=   0.0s
# [CV 17/30] END ..................alpha=4.9;, score=-89890.636 total time=   0.0s
# [CV 18/30] END ..................alpha=4.9;, score=-72433.174 total time=   0.0s
# [CV 19/30] END ..................alpha=4.9;, score=-74649.538 total time=   0.0s
# [CV 20/30] END ..................alpha=4.9;, score=-72509.286 total time=   0.0s
# [CV 21/30] END ..................alpha=4.9;, score=-92721.318 total time=   0.0s
# [CV 22/30] END ..................alpha=4.9;, score=-81805.086 total time=   0.0s
# [CV 23/30] END ..................alpha=4.9;, score=-80453.191 total time=   0.0s
# [CV 24/30] END ..................alpha=4.9;, score=-93385.608 total time=   0.0s
# [CV 25/30] END .................alpha=4.9;, score=-123908.810 total time=   0.0s
# [CV 26/30] END ..................alpha=4.9;, score=-71136.595 total time=   0.0s
# [CV 27/30] END ..................alpha=4.9;, score=-76687.790 total time=   0.0s
# [CV 28/30] END ..................alpha=4.9;, score=-80685.999 total time=   0.0s
# [CV 29/30] END ..................alpha=4.9;, score=-89977.003 total time=   0.0s
# [CV 30/30] END ..................alpha=4.9;, score=-78449.941 total time=   0.0s
# The best alpha value is 4.9
#             RMSE       MAE     R2
# Lasso  72604.193  60654.32  0.942
# Ridge        NaN       NaN    NaN

# %%
## Fitting the Ridge model and making predictions

model = Ridge(random_state = 4) #alpha will be adjusted in the gridsearch
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

clf = GridSearchCV(model, parameters, cv = cv, n_jobs=1, scoring = 'neg_root_mean_squared_error')
# remember parameters is set above as a global parameter

clf.fit(X=X_train_encoded, y=y_train)
ridge_model = clf.best_estimator_

print('The best alpha value is {}'.format(clf.best_params_['alpha']))

y_pred = ridge_model.predict(X_test_encoded)

results_reg = get_reg_results(y_test, y_pred, results_reg, 'Ridge')
results_reg
# Out:
# The best alpha value is 0.1
#             RMSE        MAE     R2
# Lasso  72604.193   60654.32  0.942
# Ridge  72644.504  60699.709  0.942

# %% [markdown]
# ## Suppor Vector Machines/ Classification <a name="svm"></a>

# %% [markdown]
# Support-vector machines are supervised learning models that analyse data used for classification and regression analysis.
# The objective of the support vector machine algorithm is to find a hyperplane in an N-dimensional space(N — the number of features) that distinctly classifies the data points. To separate the two classes of data points, there are many possible hyperplanes that could be chosen. Our objective is to find a plane that has the maximum margin, i.e the maximum distance between data points of both classes. Maximizing the margin distance provides some reinforcement so that future data points can be classified with more confidence. The best hyperplane is that plane that has the maximum distance from both the classes, and this is the main aim of SVM.
#
# <img src="svm.png" width="550" align="center">
#
# Hyperplanes are decision boundaries that help classify the data points. Data points falling on either side of the hyperplane can be attributed to different classes. Also, the dimension of the hyperplane depends upon the number of features. If the number of input features is 2, then the hyperplane is just a line. If the number of input features is 3, then the hyperplane becomes a two-dimensional plane, etc.
#
# **Kernel**
#
# The concept of kernels in SVM allows us to separate non-linearly separable data points. In simple terms, a kernel is like a mathematical function that takes the original data and transforms it into a higher-dimensional space where it becomes easier to separate the data points with a straight line or hyperplane.
#
# Imagine that the data points cannot be perfectly separated by a straight line in 2D, but if you transform them to a higher-dimensional space using a kernel, they can be separated by a hyperplane. Kernels essentially help us to find more complex decision boundaries in the original space by projecting the data points into a higher-dimensional space where they become linearly separable.
#
# Some commonly used kernels in SVM include the linear kernel (for linearly separable data), polynomial kernel, and radial basis function (RBF) kernel. Each kernel has its own mathematical formula to transform the data points into a higher-dimensional space.
#
# <img src="kernel.png" width="550" align="center">
#
# In general, SVM classifers work better when the data is in the same magnitude, hence we would want to do feature scaling. The main advantage of standardizing is to avoid attributes in greater numeric ranges dominating those in smaller numeric ranges. Another advantage is to avoid numerical difficulties during the calculation. Because kernel values usually depend on the inner products of
# feature vectors, e.g. the linear kernel and the polynomial kernel, large attribute values might cause numerical problems.
#
#
# *Note: all graphs taken from [this guide on SVM](https://www.analyticsvidhya.com/blog/2021/10/support-vector-machinessvm-a-complete-guide-for-beginners/).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1379 entries, 0 to 1467
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   saleprice            1379 non-null   float64
#  1   property_type        1379 non-null   object
#  2   bedrooms             1379 non-null   int64
#  3   bathrooms            1379 non-null   int64
#  4   distance_to_station  1379 non-null   float64
#  5   tenure               1188 non-null   object
#  6   crime_rate           1021 non-null   float64
#  7   total_area           1379 non-null   float64
#  8   year_built           1379 non-null   int64
#  9   property_condition   1379 non-null   float64
#  10  amenities_rating     1379 non-null   float64
#  11  garden               1379 non-null   bool
#  12  balcony              1379 non-null   bool
#  13  fuel_type            1379 non-null   object
#  14  sold_under_90days    1379 non-null   int32
# dtypes: bool(2), float64(6), int32(1), int64(3), object(3)
# memory usage: 148.1+ KB

# %%
# Train Test Split with on target variable for SVM Classification
X_train, X_test, y_train, y_test = train_test_split(X_class, y_class,test_size=0.2,random_state=456)

# Resetting index to make sure our ReSampler function works
X_train.reset_index(drop=True, inplace = True)
y_train.reset_index(drop=True, inplace = True)

# Standardisation
scaler = StandardScaler()
scaler.fit(X_train.loc[:, num_vars])
X_train.loc[:, num_vars] = scaler.transform(X_train.loc[:, num_vars])
X_test.loc[:,num_vars] = scaler.transform(X_test.loc[:, num_vars])

# Imputataion
X_train_imputed = impute_missing_values(X_train)
X_test_imputed = impute_missing_values(X_test)

## One-hot encoding on categorical columsn before training the model 
X_train_encoded = pd.get_dummies(X_train_imputed, columns=['property_type','tenure','fuel_type'])
X_test_encoded = pd.get_dummies(X_test_imputed, columns=['property_type', 'tenure','fuel_type'])

# Oversample with Lukas's function using SMOTE 
X_train_resampled, y_train_resampled = ReSampler(X_train_encoded, y_train,"sold_under_90days",0.5,"SMOTE",123)
# Out:
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:109: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   StandardMinoritydf=StandardMinoritydf.append(ResampledDf)
# C:\Users\Alicia Suen\AppData\Local\Temp\ipykernel_3464\2017165140.py:125: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   NewDf=Majoritydf.append(NewDf)

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn import svm
# Parameter grid 
svm_param = {'C': [0.1, 1, 10, 100], 
              'gamma': [1, 0.1, 0.01, 0.001], 
              'kernel': ['linear', 'rbf','poly']}

# Create an SVM classifier
svm = svm.SVC(random_state = 423, probability = True)

#Fit both Grid and Random Search - for comparison
svm_class_grid = GridSearchCV(svm, svm_param, scoring='accuracy', cv=3, verbose = 3, n_jobs = 1)
svm_class_random = RandomizedSearchCV(svm, svm_param, scoring='accuracy', cv=3, verbose = 3, n_iter= 10, n_jobs = 1, random_state = 123)

# Fit the classifiers to the training data
svm_class_grid.fit(X_train_resampled, y_train_resampled)
svm_class_random.fit(X_train_resampled, y_train_resampled)
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [CV 1/3] END .....C=0.1, gamma=1, kernel=linear;, score=0.673 total time=   0.1s
# [CV 2/3] END .....C=0.1, gamma=1, kernel=linear;, score=0.659 total time=   0.0s
# [CV 3/3] END .....C=0.1, gamma=1, kernel=linear;, score=0.680 total time=   0.0s
# [CV 1/3] END ........C=0.1, gamma=1, kernel=rbf;, score=0.559 total time=   0.3s
# [CV 2/3] END ........C=0.1, gamma=1, kernel=rbf;, score=0.913 total time=   0.2s
# [CV 3/3] END ........C=0.1, gamma=1, kernel=rbf;, score=0.680 total time=   0.2s
# [CV 1/3] END .......C=0.1, gamma=1, kernel=poly;, score=0.825 total time=   0.0s
# [CV 2/3] END .......C=0.1, gamma=1, kernel=poly;, score=0.897 total time=   0.0s
# [CV 3/3] END .......C=0.1, gamma=1, kernel=poly;, score=0.928 total time=   0.1s
# [CV 1/3] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.673 total time=   0.1s
# [CV 2/3] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.659 total time=   0.0s
# [CV 3/3] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.680 total time=   0.0s
# [CV 1/3] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.831 total time=   0.2s
# [CV 2/3] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.867 total time=   0.2s
# [CV 3/3] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.882 total time=   0.2s
# [CV 1/3] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.840 total time=   0.0s
# [CV 2/3] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.893 total time=   0.0s
# [CV 3/3] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.913 total time=   0.1s
# [CV 1/3] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.673 total time=   0.1s
# [CV 2/3] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.659 total time=   0.1s
# [CV 3/3] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.680 total time=   0.0s
# [CV 1/3] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.676 total time=   0.2s
# [CV 2/3] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.652 total time=   0.2s
# [CV 3/3] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.680 total time=   0.2s
# [CV 1/3] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.498 total time=   0.1s
# [CV 2/3] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.499 total time=   0.1s
# [CV 3/3] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.499 total time=   0.1s
# [CV 1/3] END .C=0.1, gamma=0.001, kernel=linear;, score=0.673 total time=   0.1s
# [CV 2/3] END .C=0.1, gamma=0.001, kernel=linear;, score=0.659 total time=   0.0s
# [CV 3/3] END .C=0.1, gamma=0.001, kernel=linear;, score=0.680 total time=   0.1s
# [CV 1/3] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.654 total time=   0.3s
# [CV 2/3] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.499 total time=   0.3s
# [CV 3/3] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.499 total time=   0.3s
# [CV 1/3] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.498 total time=   0.1s
# [CV 2/3] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.499 total time=   0.1s
# [CV 3/3] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.499 total time=   0.1s
# [CV 1/3] END .......C=1, gamma=1, kernel=linear;, score=0.673 total time=   0.2s
# [CV 2/3] END .......C=1, gamma=1, kernel=linear;, score=0.659 total time=   0.2s
# [CV 3/3] END .......C=1, gamma=1, kernel=linear;, score=0.685 total time=   0.1s
# [CV 1/3] END ..........C=1, gamma=1, kernel=rbf;, score=0.756 total time=   0.2s
# [CV 2/3] END ..........C=1, gamma=1, kernel=rbf;, score=0.959 total time=   0.2s
# [CV 3/3] END ..........C=1, gamma=1, kernel=rbf;, score=0.969 total time=   0.3s
# [CV 1/3] END .........C=1, gamma=1, kernel=poly;, score=0.803 total time=   0.0s
# [CV 2/3] END .........C=1, gamma=1, kernel=poly;, score=0.908 total time=   0.1s
# [CV 3/3] END .........C=1, gamma=1, kernel=poly;, score=0.913 total time=   0.2s
# [CV 1/3] END .....C=1, gamma=0.1, kernel=linear;, score=0.673 total time=   0.2s
# [CV 2/3] END .....C=1, gamma=0.1, kernel=linear;, score=0.659 total time=   0.2s
# [CV 3/3] END .....C=1, gamma=0.1, kernel=linear;, score=0.685 total time=   0.1s
# [CV 1/3] END ........C=1, gamma=0.1, kernel=rbf;, score=0.869 total time=   0.1s
# [CV 2/3] END ........C=1, gamma=0.1, kernel=rbf;, score=0.904 total time=   0.1s
# [CV 3/3] END ........C=1, gamma=0.1, kernel=rbf;, score=0.910 total time=   0.1s
# [CV 1/3] END .......C=1, gamma=0.1, kernel=poly;, score=0.871 total time=   0.0s
# [CV 2/3] END .......C=1, gamma=0.1, kernel=poly;, score=0.902 total time=   0.0s
# [CV 3/3] END .......C=1, gamma=0.1, kernel=poly;, score=0.926 total time=   0.0s
# [CV 1/3] END ....C=1, gamma=0.01, kernel=linear;, score=0.673 total time=   0.2s
# [CV 2/3] END ....C=1, gamma=0.01, kernel=linear;, score=0.659 total time=   0.2s
# [CV 3/3] END ....C=1, gamma=0.01, kernel=linear;, score=0.685 total time=   0.2s
# [CV 1/3] END .......C=1, gamma=0.01, kernel=rbf;, score=0.761 total time=   0.2s
# [CV 2/3] END .......C=1, gamma=0.01, kernel=rbf;, score=0.755 total time=   0.2s
# [CV 3/3] END .......C=1, gamma=0.01, kernel=rbf;, score=0.775 total time=   0.2s
# [CV 1/3] END ......C=1, gamma=0.01, kernel=poly;, score=0.544 total time=   0.1s
# [CV 2/3] END ......C=1, gamma=0.01, kernel=poly;, score=0.525 total time=   0.1s
# [CV 3/3] END ......C=1, gamma=0.01, kernel=poly;, score=0.530 total time=   0.1s
# [CV 1/3] END ...C=1, gamma=0.001, kernel=linear;, score=0.673 total time=   0.2s
# [CV 2/3] END ...C=1, gamma=0.001, kernel=linear;, score=0.659 total time=   0.2s
# [CV 3/3] END ...C=1, gamma=0.001, kernel=linear;, score=0.685 total time=   0.2s
# [CV 1/3] END ......C=1, gamma=0.001, kernel=rbf;, score=0.673 total time=   0.2s
# [CV 2/3] END ......C=1, gamma=0.001, kernel=rbf;, score=0.656 total time=   0.2s
# [CV 3/3] END ......C=1, gamma=0.001, kernel=rbf;, score=0.678 total time=   0.2s
# [CV 1/3] END .....C=1, gamma=0.001, kernel=poly;, score=0.498 total time=   0.1s
# [CV 2/3] END .....C=1, gamma=0.001, kernel=poly;, score=0.499 total time=   0.1s
# [CV 3/3] END .....C=1, gamma=0.001, kernel=poly;, score=0.499 total time=   0.1s
# [CV 1/3] END ......C=10, gamma=1, kernel=linear;, score=0.673 total time=   1.0s
# [CV 2/3] END ......C=10, gamma=1, kernel=linear;, score=0.659 total time=   0.8s
# [CV 3/3] END ......C=10, gamma=1, kernel=linear;, score=0.687 total time=   0.9s
# [CV 1/3] END .........C=10, gamma=1, kernel=rbf;, score=0.772 total time=   0.3s
# [CV 2/3] END .........C=10, gamma=1, kernel=rbf;, score=0.956 total time=   0.2s
# [CV 3/3] END .........C=10, gamma=1, kernel=rbf;, score=0.967 total time=   0.3s
# [CV 1/3] END ........C=10, gamma=1, kernel=poly;, score=0.803 total time=   0.0s
# [CV 2/3] END ........C=10, gamma=1, kernel=poly;, score=0.908 total time=   0.2s
# [CV 3/3] END ........C=10, gamma=1, kernel=poly;, score=0.908 total time=   0.2s
# [CV 1/3] END ....C=10, gamma=0.1, kernel=linear;, score=0.673 total time=   1.0s
# [CV 2/3] END ....C=10, gamma=0.1, kernel=linear;, score=0.659 total time=   0.8s
# [CV 3/3] END ....C=10, gamma=0.1, kernel=linear;, score=0.687 total time=   0.9s
# [CV 1/3] END .......C=10, gamma=0.1, kernel=rbf;, score=0.875 total time=   0.0s
# [CV 2/3] END .......C=10, gamma=0.1, kernel=rbf;, score=0.930 total time=   0.0s
# [CV 3/3] END .......C=10, gamma=0.1, kernel=rbf;, score=0.934 total time=   0.0s
# [CV 1/3] END ......C=10, gamma=0.1, kernel=poly;, score=0.869 total time=   0.0s
# [CV 2/3] END ......C=10, gamma=0.1, kernel=poly;, score=0.913 total time=   0.0s
# [CV 3/3] END ......C=10, gamma=0.1, kernel=poly;, score=0.939 total time=   0.0s
# [CV 1/3] END ...C=10, gamma=0.01, kernel=linear;, score=0.673 total time=   1.0s
# [CV 2/3] END ...C=10, gamma=0.01, kernel=linear;, score=0.659 total time=   0.9s
# [CV 3/3] END ...C=10, gamma=0.01, kernel=linear;, score=0.687 total time=   0.8s
# [CV 1/3] END ......C=10, gamma=0.01, kernel=rbf;, score=0.855 total time=   0.1s
# [CV 2/3] END ......C=10, gamma=0.01, kernel=rbf;, score=0.866 total time=   0.1s
# [CV 3/3] END ......C=10, gamma=0.01, kernel=rbf;, score=0.886 total time=   0.1s
# [CV 1/3] END .....C=10, gamma=0.01, kernel=poly;, score=0.673 total time=   0.1s
# [CV 2/3] END .....C=10, gamma=0.01, kernel=poly;, score=0.626 total time=   0.1s
# [CV 3/3] END .....C=10, gamma=0.01, kernel=poly;, score=0.694 total time=   0.1s
# [CV 1/3] END ..C=10, gamma=0.001, kernel=linear;, score=0.673 total time=   1.0s
# [CV 2/3] END ..C=10, gamma=0.001, kernel=linear;, score=0.659 total time=   0.9s
# [CV 3/3] END ..C=10, gamma=0.001, kernel=linear;, score=0.687 total time=   0.8s
# [CV 1/3] END .....C=10, gamma=0.001, kernel=rbf;, score=0.673 total time=   0.2s
# [CV 2/3] END .....C=10, gamma=0.001, kernel=rbf;, score=0.656 total time=   0.2s
# [CV 3/3] END .....C=10, gamma=0.001, kernel=rbf;, score=0.678 total time=   0.2s
# [CV 1/3] END ....C=10, gamma=0.001, kernel=poly;, score=0.498 total time=   0.1s
# [CV 2/3] END ....C=10, gamma=0.001, kernel=poly;, score=0.499 total time=   0.1s
# [CV 3/3] END ....C=10, gamma=0.001, kernel=poly;, score=0.499 total time=   0.1s
# [CV 1/3] END .....C=100, gamma=1, kernel=linear;, score=0.673 total time=  29.8s
# [CV 2/3] END .....C=100, gamma=1, kernel=linear;, score=0.659 total time=  43.8s
# [CV 3/3] END .....C=100, gamma=1, kernel=linear;, score=0.689 total time=  15.8s
# [CV 1/3] END ........C=100, gamma=1, kernel=rbf;, score=0.772 total time=   0.2s
# [CV 2/3] END ........C=100, gamma=1, kernel=rbf;, score=0.956 total time=   0.3s
# [CV 3/3] END ........C=100, gamma=1, kernel=rbf;, score=0.967 total time=   0.3s
# [CV 1/3] END .......C=100, gamma=1, kernel=poly;, score=0.803 total time=   0.0s
# [CV 2/3] END .......C=100, gamma=1, kernel=poly;, score=0.908 total time=   0.2s
# [CV 3/3] END .......C=100, gamma=1, kernel=poly;, score=0.908 total time=   0.2s
# [CV 1/3] END ...C=100, gamma=0.1, kernel=linear;, score=0.673 total time=  30.3s
# [CV 2/3] END ...C=100, gamma=0.1, kernel=linear;, score=0.659 total time=  43.7s
# [CV 3/3] END ...C=100, gamma=0.1, kernel=linear;, score=0.689 total time=  16.5s
# [CV 1/3] END ......C=100, gamma=0.1, kernel=rbf;, score=0.853 total time=   0.0s
# [CV 2/3] END ......C=100, gamma=0.1, kernel=rbf;, score=0.952 total time=   0.1s
# [CV 3/3] END ......C=100, gamma=0.1, kernel=rbf;, score=0.932 total time=   0.1s
# [CV 1/3] END .....C=100, gamma=0.1, kernel=poly;, score=0.825 total time=   0.0s
# [CV 2/3] END .....C=100, gamma=0.1, kernel=poly;, score=0.897 total time=   0.1s
# [CV 3/3] END .....C=100, gamma=0.1, kernel=poly;, score=0.928 total time=   0.1s
# [CV 1/3] END ..C=100, gamma=0.01, kernel=linear;, score=0.673 total time=  30.7s
# [CV 2/3] END ..C=100, gamma=0.01, kernel=linear;, score=0.659 total time=  43.4s
# [CV 3/3] END ..C=100, gamma=0.01, kernel=linear;, score=0.689 total time=  16.0s
# [CV 1/3] END .....C=100, gamma=0.01, kernel=rbf;, score=0.860 total time=   0.1s
# [CV 2/3] END .....C=100, gamma=0.01, kernel=rbf;, score=0.893 total time=   0.1s
# [CV 3/3] END .....C=100, gamma=0.01, kernel=rbf;, score=0.921 total time=   0.1s
# [CV 1/3] END ....C=100, gamma=0.01, kernel=poly;, score=0.840 total time=   0.0s
# [CV 2/3] END ....C=100, gamma=0.01, kernel=poly;, score=0.893 total time=   0.0s
# [CV 3/3] END ....C=100, gamma=0.01, kernel=poly;, score=0.913 total time=   0.0s
# [CV 1/3] END .C=100, gamma=0.001, kernel=linear;, score=0.673 total time=  30.8s
# [CV 2/3] END .C=100, gamma=0.001, kernel=linear;, score=0.659 total time=  49.3s
# [CV 3/3] END .C=100, gamma=0.001, kernel=linear;, score=0.689 total time=  18.5s
# [CV 1/3] END ....C=100, gamma=0.001, kernel=rbf;, score=0.768 total time=   0.2s
# [CV 2/3] END ....C=100, gamma=0.001, kernel=rbf;, score=0.770 total time=   0.2s
# [CV 3/3] END ....C=100, gamma=0.001, kernel=rbf;, score=0.775 total time=   0.2s
# [CV 1/3] END ...C=100, gamma=0.001, kernel=poly;, score=0.498 total time=   0.1s
# [CV 2/3] END ...C=100, gamma=0.001, kernel=poly;, score=0.499 total time=   0.1s
# [CV 3/3] END ...C=100, gamma=0.001, kernel=poly;, score=0.499 total time=   0.1s
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END ....C=1, gamma=0.01, kernel=linear;, score=0.673 total time=   0.2s
# [CV 2/3] END ....C=1, gamma=0.01, kernel=linear;, score=0.659 total time=   0.2s
# [CV 3/3] END ....C=1, gamma=0.01, kernel=linear;, score=0.685 total time=   0.1s
# [CV 1/3] END ..........C=1, gamma=1, kernel=rbf;, score=0.756 total time=   0.2s
# [CV 2/3] END ..........C=1, gamma=1, kernel=rbf;, score=0.959 total time=   0.2s
# [CV 3/3] END ..........C=1, gamma=1, kernel=rbf;, score=0.969 total time=   0.3s
# [CV 1/3] END ........C=10, gamma=1, kernel=poly;, score=0.803 total time=   0.0s
# [CV 2/3] END ........C=10, gamma=1, kernel=poly;, score=0.908 total time=   0.2s
# [CV 3/3] END ........C=10, gamma=1, kernel=poly;, score=0.908 total time=   0.2s
# [CV 1/3] END ......C=10, gamma=0.01, kernel=rbf;, score=0.855 total time=   0.1s
# [CV 2/3] END ......C=10, gamma=0.01, kernel=rbf;, score=0.866 total time=   0.1s
# [CV 3/3] END ......C=10, gamma=0.01, kernel=rbf;, score=0.886 total time=   0.1s
# [CV 1/3] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.654 total time=   0.2s
# [CV 2/3] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.499 total time=   0.2s
# [CV 3/3] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.499 total time=   0.2s
# [CV 1/3] END ......C=100, gamma=0.1, kernel=rbf;, score=0.853 total time=   0.0s
# [CV 2/3] END ......C=100, gamma=0.1, kernel=rbf;, score=0.952 total time=   0.1s
# [CV 3/3] END ......C=100, gamma=0.1, kernel=rbf;, score=0.932 total time=   0.1s
# [CV 1/3] END ...C=100, gamma=0.1, kernel=linear;, score=0.673 total time=  39.6s
# [CV 2/3] END ...C=100, gamma=0.1, kernel=linear;, score=0.659 total time=  57.3s
# [CV 3/3] END ...C=100, gamma=0.1, kernel=linear;, score=0.689 total time=  21.0s
# [CV 1/3] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.498 total time=   0.1s
# [CV 2/3] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.499 total time=   0.1s
# [CV 3/3] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.499 total time=   0.1s
# [CV 1/3] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.498 total time=   0.2s
# [CV 2/3] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.499 total time=   0.2s
# [CV 3/3] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.499 total time=   0.1s
# [CV 1/3] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.840 total time=   0.1s
# [CV 2/3] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.893 total time=   0.1s
# [CV 3/3] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.913 total time=   0.1s
# RandomizedSearchCV(cv=3, estimator=SVC(probability=True, random_state=423),
#                    n_jobs=1,
#                    param_distributions={'C': [0.1, 1, 10, 100],
#                                         'gamma': [1, 0.1, 0.01, 0.001],
#                                         'kernel': ['linear', 'rbf', 'poly']},
#                    random_state=123, scoring='accuracy', verbose=3)

# %%
#Get the Grid Search Results
GridResultsSV=pd.DataFrame(svm_class_grid.cv_results_) # We make them a pandas dataframe, just it because it looks nice
GridResultsSV=GridResultsSV.sort_values("rank_test_score") #And we sort them by rank
GridResultsSV.head(1)

#Get the Random Search Results
RandomResultsSV=pd.DataFrame(svm_class_random.cv_results_) # We make them a pandas dataframe, just it because it looks nice
RandomResultsSV=RandomResultsSV.sort_values("rank_test_score") #And we sort them by rank
RandomResultsSV.head(1)

#Print what we have found - Check out how much quicker Random is than Grid
print(f'Grid Search took {GridResultsSV.mean_fit_time.sum()*3} seconds to fit. The best fit is {GridResultsSV.mean_test_score[0]}')
print(f'Random Search took {RandomResultsSV.mean_fit_time.sum()*3} seconds to fit. The best fit is {RandomResultsSV.mean_test_score[0]}')
# Out:
# Grid Search took 405.6396188735962 seconds to fit. The best fit ist 0.6705507709529485
# Random Search took 124.1187515258789 seconds to fit. The best fit ist 0.6723923915790994

# %%
#Get the best estimators
svm_model = svm_class_grid.best_estimator_

y_pred = svm_model.predict(X_test_encoded)
y_probs = svm_model.predict_proba(X_test_encoded)[:, 1]  # Probability estimates of the positive class, need this to calculate auc

results_class = get_classification_results(y_test, y_pred, results_class, 'SVM')

# %%
results_class
# Out:
#                    accuracy        f1 precision    recall       auc     kappa
# Random Forest      0.789855  0.865741  0.802575  0.939698  0.813418  0.395879
# Gradient Boosting   0.76087  0.842857  0.800905  0.889447  0.789402  0.348544
# SVM                0.884058  0.919192  0.923858  0.914573  0.923579  0.714082

# %% [markdown]
# ## Activity - your turn! <a name="activity"></a>
#
# Today, you have two choices! One is to explore hyperparameter tuning either going through the Telecom Churn dataset or you can start data preparation work on your own project!
